# %%
from typing import List, Dict, Any, Optional, Tuple, Iterable

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os

# %% [markdown]
# 載入價格

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# 讀取NAS100資料
def load_nas100_data(file_path):
    """載入並預處理NAS100資料"""
    df = pd.read_csv(file_path)
    
    # 轉換時間格式
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
    
    # 使用BidClose作為主要價格
    df['Close'] = df['BidClose']
    df['High'] = df['BidHigh'] 
    df['Low'] = df['BidLow']
    df['Open'] = df['BidOpen']
    
    return df[['Open', 'High', 'Low', 'Close', 'Volume']]

# 資料重採樣
def resample_data(df, interval='1H'):
    """將15分鐘資料重採樣為指定間隔"""
    resampled = df.resample(interval).agg({
        'Open': 'first',
        'High': 'max',
        'Low': 'min', 
        'Close': 'last',
        'Volume': 'sum'
    }).dropna()
    
    return resampled

# 執行資料載入和重採樣
nas100_raw = load_nas100_data('equity_prices/XAUUSD.csv')

# # 僅保留 2015-11-01 之後
nas100_raw = nas100_raw.loc[nas100_raw.index >= '2018-11-01']
nas100_raw

# nas100_hourly = resample_data(nas100_raw, '1H')

# print(f"原始資料筆數: {len(nas100_raw)}")
# print(f"重採樣後筆數: {len(nas100_hourly)}")
# print(f"資料期間: {nas100_hourly.index[0]} 至 {nas100_hourly.index[-1]}")
# Out:
#                         Open     High      Low    Close  Volume
# Date
# 2018-11-01 00:00:00  1215.90  1216.68  1215.82  1216.36    1933
# 2018-11-01 00:15:00  1216.36  1217.20  1216.14  1216.75    2623
# 2018-11-01 00:30:00  1216.75  1217.13  1215.83  1216.67    3958
# 2018-11-01 00:45:00  1216.67  1217.03  1216.26  1216.30    3258
# 2018-11-01 01:00:00  1216.30  1216.75  1215.79  1216.14    3136
# ...                      ...      ...      ...      ...     ...
# 2025-09-12 05:15:00  3656.01  3656.64  3652.82  3652.93    2428
# 2025-09-12 05:30:00  3652.93  3655.64  3652.09  3654.79    5567
# 2025-09-12 05:45:00  3654.79  3655.14  3651.88  3653.05    5352
# 2025-09-12 06:00:00  3653.05  3653.76  3651.01  3653.16    6362
# 2025-09-12 06:15:00  3653.16  3653.27  3652.81  3653.16     126
#
# [162577 rows x 5 columns]

# %% [markdown]
# 回測代碼

# %%
# =====================================================
# 回測系統：訊號進場 + 停損停利（支援動態槓桿調整 + 百分比停利）
# =====================================================
class BacktestEngine:
    """回測引擎：處理進場、停損、停利邏輯（支援動態槓桿調整 + 百分比停利）"""
    
    def __init__(self, stop_loss_pct=0.5, take_profit_bars=32, take_profit_pct=0.5,
                 initial_capital=100000, base_leverage=1.0):
        """
        Parameters:
        -----------
        stop_loss_pct : float
            停損百分比（預設 0.0025 = 0.25%）
        take_profit_bars : int
            停利K線數（預設 32）
        take_profit_pct : float
            停利百分比（預設 0.0025 = 0.25%）
        initial_capital : float
            初始資金（預設 100000）
        base_leverage : float
            基礎槓桿倍數（預設 1.0，如果沒有提供動態槓桿時使用）
        """
        self.stop_loss_pct = stop_loss_pct
        self.take_profit_bars = take_profit_bars
        self.take_profit_pct = take_profit_pct
        self.initial_capital = initial_capital
        self.base_leverage = base_leverage
        self.trades = []
        self.price_df = None  # 保存價格數據供 Buy and Hold 計算使用
        
    def backtest(self, df: pd.DataFrame, signals: pd.Series, 
                 leverage_series: pd.Series = None) -> pd.DataFrame:
        """
        執行回測（支援動態槓桿調整）
        
        Parameters:
        -----------
        df : pd.DataFrame
            價格資料（需包含 'Close', 'High', 'Low' 欄位）
        signals : pd.Series
            進場信號（True 表示進場點，需與 df 的 index 對齊）
        leverage_series : pd.Series, optional
            每筆交易的槓桿倍數（需與 df 的 index 對齊）
            如果為None，則所有交易使用base_leverage
            
        Returns:
        --------
        results : pd.DataFrame
            回測結果，包含每筆交易的詳細資訊
        """
        df = df.copy()
        signals = signals.copy()
        
        # 保存價格數據供後續使用（用於 buy and hold 計算）
        self.price_df = df.copy()
        
        # 確保 signals 與 df 的 index 對齊
        if not signals.index.equals(df.index):
            signals = signals.reindex(df.index, fill_value=False)
        
        # 處理槓桿倍數
        if leverage_series is None:
            leverage_series = pd.Series(self.base_leverage, index=df.index)
        else:
            leverage_series = leverage_series.copy()
            if not leverage_series.index.equals(df.index):
                leverage_series = leverage_series.reindex(df.index, fill_value=self.base_leverage)
        
        # 初始化狀態
        position = None  # None: 無持倉, dict: {entry_time, entry_price, side, units, leverage, capital_used}
        trades = []
        current_equity = self.initial_capital  # 當前總equity
        
        for i, (timestamp, row) in enumerate(df.iterrows()):
            current_close = row['Close']
            current_high = row['High']
            current_low = row['Low']
            has_signal = signals.loc[timestamp]
            leverage = leverage_series.loc[timestamp]
            
            # ============================================
            # 邏輯1: 檢查進場條件（確保同時只會進場一次）
            # ============================================
            if has_signal and position is None:
                # 計算可進場的單位數
                # 可用資金 = 當前總equity * 槓桿倍數
                available_capital = current_equity * leverage
                
                # 計算可買入的單位數（假設1單位 = 1價格）
                # 實際應用中可能需要根據合約規格調整
                units = (available_capital / current_close) * 1
                
                # 實際使用的資金（不考慮槓桿時的資金）
                capital_used = current_equity
                
                # 以收盤價進場（做多）
                position = {
                    'entry_time': timestamp,
                    'entry_price': current_close,
                    'entry_idx': i,
                    'side': 1,  # 1 = 做多
                    'units': units,  # 進場單位數
                    'leverage': leverage,  # 使用的槓桿倍數
                    'capital_used': capital_used  # 使用的資金
                }
                continue
            
            # ============================================
            # 邏輯2: 如果有持倉，檢查停損停利
            # ============================================
            if position is not None:
                entry_price = position['entry_price']
                entry_idx = position['entry_idx']
                side = position['side']
                units = position['units']
                leverage_used = position['leverage']
                capital_used = position['capital_used']
                
                # 計算停損價格
                stop_loss_price = entry_price * (1 - self.stop_loss_pct * side)
                
                # 計算停利價格
                take_profit_price = entry_price * (1 + self.take_profit_pct * side)
                
                # 計算持倉K線數
                bars_held = i - entry_idx
                
                # 檢查停損（使用當根K的最低價）
                hit_stop_loss = False
                exit_price = None
                exit_reason = None
                
                if side == 1:  # 做多
                    if current_low <= stop_loss_price:
                        hit_stop_loss = True
                        exit_price = stop_loss_price
                        exit_reason = 'Stop Loss'
                
                # 檢查百分比停利（使用當根K的最高價）
                hit_take_profit_pct = False
                if side == 1:  # 做多
                    if current_high >= take_profit_price:
                        hit_take_profit_pct = True
                        exit_price = take_profit_price
                        exit_reason = 'Take Profit (0.25%)'
                
                # 檢查時間停利（32根K後以收盤價平倉）
                hit_take_profit_bars = False
                if bars_held >= self.take_profit_bars:
                    hit_take_profit_bars = True
                    # 如果還沒觸發百分比停利，才使用時間停利
                    if not hit_take_profit_pct:
                        exit_price = current_close
                        exit_reason = 'Take Profit (32 bars)'
                
                # 如果觸發停損或停利，執行平倉
                if hit_stop_loss or hit_take_profit_pct or hit_take_profit_bars:
                    # 計算實際盈虧金額
                    # 盈虧 = (出場價 - 進場價) * 單位數 * 方向
                    pnl = (exit_price - entry_price - entry_price*0.0001) * units * side 
                    
                    # 計算報酬率（相對於使用的資金）
                    return_pct = (pnl / capital_used) * 100 if capital_used > 0 else 0
                    
                    # 更新當前總equity
                    current_equity = current_equity + pnl
                    
                    # 記錄交易
                    trade = {
                        'entry_time': position['entry_time'],
                        'exit_time': timestamp,
                        'entry_price': entry_price,
                        'exit_price': exit_price,
                        'side': side,
                        'units': units,
                        'leverage': leverage_used,
                        'capital_used': capital_used,
                        'pnl': pnl,  # 盈虧金額
                        'return_pct': return_pct,  # 報酬率
                        'bars_held': bars_held,
                        'exit_reason': exit_reason,
                        'stop_loss_price': stop_loss_price,
                        'take_profit_price': take_profit_price,
                        'equity_after': current_equity  # 平倉後總equity
                    }
                    trades.append(trade)
                    
                    # 重置持倉
                    position = None
        
        # 處理最後一筆未平倉的交易（如果有的話）
        if position is not None:
            last_timestamp = df.index[-1]
            last_close = df['Close'].iloc[-1]
            entry_price = position['entry_price']
            side = position['side']
            units = position['units']
            leverage_used = position['leverage']
            capital_used = position['capital_used']
            bars_held = len(df) - 1 - position['entry_idx']
            
            pnl = (last_close - entry_price) * units * side
            return_pct = (pnl / capital_used) * 100 if capital_used > 0 else 0
            current_equity = current_equity + pnl
            
            trade = {
                'entry_time': position['entry_time'],
                'exit_time': last_timestamp,
                'entry_price': entry_price,
                'exit_price': last_close,
                'side': side,
                'units': units,
                'leverage': leverage_used,
                'capital_used': capital_used,
                'pnl': pnl,
                'return_pct': return_pct,
                'bars_held': bars_held,
                'exit_reason': 'End of Data',
                'stop_loss_price': entry_price * (1 - self.stop_loss_pct * side),
                'take_profit_price': entry_price * (1 + self.take_profit_pct * side),
                'equity_after': current_equity
            }
            trades.append(trade)
        
        # 轉換為 DataFrame
        if trades:
            results = pd.DataFrame(trades)
            self.trades = results
            self.final_equity = current_equity
            return results
        else:
            print("⚠️ 沒有產生任何交易")
            self.final_equity = current_equity
            return pd.DataFrame()
    
    def get_performance_metrics(self) -> dict:
        """計算績效指標"""
        if len(self.trades) == 0:
            return {}
        
        df = self.trades
        
        total_trades = len(df)
        winning_trades = len(df[df['pnl'] > 0])
        losing_trades = len(df[df['pnl'] < 0])
        
        win_rate = winning_trades / total_trades if total_trades > 0 else 0
        
        total_pnl = df['pnl'].sum()
        total_return_pct = ((self.final_equity - self.initial_capital) / self.initial_capital) * 100
        avg_return = df['return_pct'].mean()
        
        avg_win = df[df['pnl'] > 0]['return_pct'].mean() if winning_trades > 0 else 0
        avg_loss = df[df['pnl'] < 0]['return_pct'].mean() if losing_trades > 0 else 0
        
        avg_win_amount = df[df['pnl'] > 0]['pnl'].mean() if winning_trades > 0 else 0
        avg_loss_amount = df[df['pnl'] < 0]['pnl'].mean() if losing_trades > 0 else 0
        
        profit_factor = abs(avg_win_amount * winning_trades / (avg_loss_amount * losing_trades)) if losing_trades > 0 and avg_loss_amount != 0 else np.inf
        
        # 統計停損停利次數
        stop_loss_count = len(df[df['exit_reason'] == 'Stop Loss'])
        take_profit_pct_count = len(df[df['exit_reason'] == 'Take Profit (0.25%)'])
        take_profit_bars_count = len(df[df['exit_reason'] == 'Take Profit (32 bars)'])
        
        # 統計32根K後的賺錢和虧錢出場
        take_profit_bars_trades = df[df['exit_reason'] == 'Take Profit (32 bars)']
        take_profit_bars_win = len(take_profit_bars_trades[take_profit_bars_trades['pnl'] > 0])
        take_profit_bars_loss = len(take_profit_bars_trades[take_profit_bars_trades['pnl'] <= 0])
        
        # 統計百分比停利的賺錢和虧錢出場
        take_profit_pct_trades = df[df['exit_reason'] == 'Take Profit (0.25%)']
        take_profit_pct_win = len(take_profit_pct_trades[take_profit_pct_trades['pnl'] > 0])
        take_profit_pct_loss = len(take_profit_pct_trades[take_profit_pct_trades['pnl'] <= 0])
        
        # 統計不同槓桿的交易
        if 'leverage' in df.columns:
            leverage_0_5 = len(df[df['leverage'] == 0.5])
            leverage_1_0 = len(df[df['leverage'] == 1.0])
            leverage_2_0 = len(df[df['leverage'] == 2.0])
        else:
            leverage_0_5 = leverage_1_0 = leverage_2_0 = 0
        
        metrics = {
            'Initial Capital': self.initial_capital,
            'Final Equity': self.final_equity,
            'Total PnL': total_pnl,
            'Total Return (%)': total_return_pct,
            'Total Trades': total_trades,
            'Winning Trades': winning_trades,
            'Losing Trades': losing_trades,
            'Win Rate (%)': win_rate * 100,
            'Average Return (%)': avg_return,
            'Average Win (%)': avg_win,
            'Average Loss (%)': avg_loss,
            'Average Win Amount': avg_win_amount,
            'Average Loss Amount': avg_loss_amount,
            'Profit Factor': profit_factor,
            'Stop Loss Count': stop_loss_count,
            'Take Profit Pct Count': take_profit_pct_count,
            'Take Profit Pct Win Count': take_profit_pct_win,
            'Take Profit Pct Loss Count': take_profit_pct_loss,
            'Take Profit Bars Count': take_profit_bars_count,
            'Take Profit Bars Win Count': take_profit_bars_win,
            'Take Profit Bars Loss Count': take_profit_bars_loss,
            'Leverage 0.5x Count': leverage_0_5,
            'Leverage 1.0x Count': leverage_1_0,
            'Leverage 2.0x Count': leverage_2_0
        }
        
        return metrics
    
    def print_summary(self):
        """印出回測摘要"""
        if len(self.trades) == 0:
            print("⚠️ 沒有交易記錄")
            return
        
        metrics = self.get_performance_metrics()
        
        print("=" * 60)
        print("📊 回測結果摘要（含動態槓桿調整 + 百分比停利）")
        print("=" * 60)
        print(f"初始資金: ${metrics['Initial Capital']:,.2f}")
        print(f"最終總equity: ${metrics['Final Equity']:,.2f}")
        print(f"總盈虧: ${metrics['Total PnL']:,.2f}")
        print(f"總報酬率: {metrics['Total Return (%)']:.2f}%")
        print(f"總交易次數: {metrics['Total Trades']:,}")
        print(f"獲利交易: {metrics['Winning Trades']:,}")
        print(f"虧損交易: {metrics['Losing Trades']:,}")
        print(f"勝率: {metrics['Win Rate (%)']:.2f}%")
        print(f"平均報酬率: {metrics['Average Return (%)']:.2f}%")
        print(f"平均獲利: {metrics['Average Win (%)']:.2f}% (${metrics['Average Win Amount']:,.2f})")
        print(f"平均虧損: {metrics['Average Loss (%)']:.2f}% (${metrics['Average Loss Amount']:,.2f})")
        print(f"獲利因子: {metrics['Profit Factor']:.2f}")
        print(f"停損次數: {metrics['Stop Loss Count']:,}")
        print(f"百分比停利次數 (0.25%): {metrics['Take Profit Pct Count']:,}")
        print(f"  0.25%停利賺錢出場: {metrics['Take Profit Pct Win Count']:,}")
        print(f"  0.25%停利虧錢出場: {metrics['Take Profit Pct Loss Count']:,}")
        print(f"時間停利次數 (32根K): {metrics['Take Profit Bars Count']:,}")
        print(f"  32根K後賺錢出場: {metrics['Take Profit Bars Win Count']:,}")
        print(f"  32根K後虧錢出場: {metrics['Take Profit Bars Loss Count']:,}")
        print(f"槓桿分布:")
        print(f"  0.5x槓桿: {metrics['Leverage 0.5x Count']:,}")
        print(f"  1.0x槓桿: {metrics['Leverage 1.0x Count']:,}")
        print(f"  2.0x槓桿: {metrics['Leverage 2.0x Count']:,}")
        print("=" * 60)
    
    def plot_equity_curve(self):
        """繪製權益曲線（含 Buy and Hold 比較 + 最大回撤標記）"""
        import matplotlib.pyplot as plt
        from datetime import datetime

        if len(self.trades) == 0:
            print("⚠️ 沒有交易記錄")
            return

        if not hasattr(self, 'price_df') or self.price_df is None:
            print("⚠️ 缺少價格數據，無法計算 Buy and Hold 績效")
            return

        df = self.trades.copy()
        price_df = self.price_df.copy()

        df['cumulative_equity'] = self.initial_capital + df['pnl'].cumsum()
        df['cumulative_return_pct'] = ((df['cumulative_equity'] - self.initial_capital) / self.initial_capital) * 100

        # 最大回撤計算
        df['running_max'] = df['cumulative_equity'].cummax()
        df['drawdown_pct'] = (df['cumulative_equity'] / df['running_max'] - 1.0) * 100
        max_dd_pct = df['drawdown_pct'].min()
        max_dd_idx = df['drawdown_pct'].idxmin()
        max_dd_end_time = df.loc[max_dd_idx, 'exit_time']
        max_dd_start_idx = df.loc[:max_dd_idx, 'cumulative_equity'].idxmax()
        max_dd_start_time = df.loc[max_dd_start_idx, 'exit_time']

        first_entry_time = df['entry_time'].iloc[0] if len(df) > 0 else price_df.index[0]
        last_time = price_df.index[-1]
        start_price = price_df.loc[price_df.index >= first_entry_time, 'Close'].iloc[0]
        end_price = price_df['Close'].iloc[-1]
        bh_return_pct = ((end_price - start_price) / start_price) * 100
        bh_final_equity = self.initial_capital * (1 + bh_return_pct / 100)

        # 計算年化收益率
        # 策略時間跨度
        strategy_start = pd.to_datetime(first_entry_time)
        strategy_end = pd.to_datetime(df['exit_time'].iloc[-1])
        strategy_years = (strategy_end - strategy_start).total_seconds() / (365.25 * 24 * 3600)
        
        # Buy and Hold 時間跨度
        bh_start = pd.to_datetime(first_entry_time)
        bh_end = pd.to_datetime(last_time)
        bh_years = (bh_end - bh_start).total_seconds() / (365.25 * 24 * 3600)
        
        # 策略年化收益率
        strategy_total_return = df['cumulative_return_pct'].iloc[-1] / 100
        if strategy_years > 0:
            strategy_annualized_return = ((1 + strategy_total_return) ** (1 / strategy_years) - 1) * 100
        else:
            strategy_annualized_return = 0
        
        # Buy and Hold 年化收益率
        bh_total_return = bh_return_pct / 100
        if bh_years > 0:
            bh_annualized_return = ((1 + bh_total_return) ** (1 / bh_years) - 1) * 100
        else:
            bh_annualized_return = 0

        strategy_period = price_df.loc[price_df.index >= first_entry_time].copy()
        strategy_period['bh_equity'] = self.initial_capital * (1 + (strategy_period['Close'] - start_price) / start_price)
        strategy_period['bh_return_pct'] = ((strategy_period['bh_equity'] - self.initial_capital) / self.initial_capital) * 100

        stop_loss_trades = df[df['exit_reason'] == 'Stop Loss']
        take_profit_pct_trades = df[df['exit_reason'] == 'Take Profit (0.25%)']
        take_profit_bars_win = df[(df['exit_reason'] == 'Take Profit (32 bars)') & (df['pnl'] > 0)]
        take_profit_bars_loss = df[(df['exit_reason'] == 'Take Profit (32 bars)') & (df['pnl'] <= 0)]
        end_of_data = df[df['exit_reason'] == 'End of Data']

        fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(14, 14))

        # Equity 曲線
        ax1.plot(df['exit_time'], df['cumulative_equity'],
                 linewidth=2, color='blue', alpha=0.7, label='Strategy Equity', marker='o', markersize=3)
        ax1.plot(strategy_period.index, strategy_period['bh_equity'],
                 linewidth=2, color='orange', alpha=0.7, label='Buy and Hold Equity', linestyle='--')
        ax1.axhline(y=self.initial_capital, color='gray', linestyle='--', alpha=0.5, label='Initial Capital')
        ax1.axvspan(max_dd_start_time, max_dd_end_time, color='red', alpha=0.1, label='Max Drawdown Window')
        ax1.annotate(f'MDD: {abs(max_dd_pct):.2f}%',
                     xy=(max_dd_end_time, df.loc[max_dd_idx, 'cumulative_equity']),
                     xytext=(0, -40), textcoords='offset points',
                     arrowprops=dict(arrowstyle='->', color='red'),
                     color='red', fontsize=10, fontweight='bold')
        ax1.set_title('Equity Curve Comparison', fontsize=14, fontweight='bold')
        ax1.set_xlabel('Time', fontsize=12)
        ax1.set_ylabel('Equity ($)', fontsize=12)
        ax1.legend(loc='best')
        ax1.grid(True, alpha=0.3)
        plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45)

        # 累積報酬率
        ax2.plot(df['exit_time'], df['cumulative_return_pct'],
                 linewidth=2, color='green', alpha=0.7, label='Strategy Return (%)', marker='o', markersize=3)
        ax2.plot(strategy_period.index, strategy_period['bh_return_pct'],
                 linewidth=2, color='orange', alpha=0.7, label='Buy and Hold Return (%)', linestyle='--')

        if len(stop_loss_trades) > 0:
            ax2.scatter(stop_loss_trades['exit_time'], stop_loss_trades['cumulative_return_pct'],
                        color='red', s=30, alpha=0.6,
                        label=f'Stop Loss ({len(stop_loss_trades)})', marker='x')
        if len(take_profit_pct_trades) > 0:
            ax2.scatter(take_profit_pct_trades['exit_time'], take_profit_pct_trades['cumulative_return_pct'],
                        color='lime', s=50, alpha=0.7,
                        label=f'0.25% Take Profit ({len(take_profit_pct_trades)})', marker='*')
        if len(take_profit_bars_win) > 0:
            ax2.scatter(take_profit_bars_win['exit_time'], take_profit_bars_win['cumulative_return_pct'],
                        color='green', s=50, alpha=0.7,
                        label=f'32 Bars Profit ({len(take_profit_bars_win)})', marker='^')
        if len(take_profit_bars_loss) > 0:
            ax2.scatter(take_profit_bars_loss['exit_time'], take_profit_bars_loss['cumulative_return_pct'],
                        color='orange', s=50, alpha=0.7,
                        label=f'32 Bars Loss ({len(take_profit_bars_loss)})', marker='v')
        if len(end_of_data) > 0:
            ax2.scatter(end_of_data['exit_time'], end_of_data['cumulative_return_pct'],
                        color='gray', s=30, alpha=0.5,
                        label=f'End of Data ({len(end_of_data)})', marker='s')

        ax2.set_title('Cumulative Return (%) Comparison', fontsize=14, fontweight='bold')
        ax2.set_xlabel('Time', fontsize=12)
        ax2.set_ylabel('Cumulative Return (%)', fontsize=12)
        ax2.axhline(y=0, color='black', linestyle='--', alpha=0.3, linewidth=1)
        ax2.legend(loc='best')
        ax2.grid(True, alpha=0.3)
        plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45)

        # 文字摘要
        ax3.axis('off')
        strategy_final_return = df['cumulative_return_pct'].iloc[-1]
        strategy_final_equity = df['cumulative_equity'].iloc[-1]
        excess_return = strategy_final_return - bh_return_pct
        excess_annualized_return = strategy_annualized_return - bh_annualized_return
        comparison_text = f"""
            Performance Comparison Summary
            {'=' * 50}
            Strategy Performance:
            Final Equity: ${strategy_final_equity:,.2f}
            Total Return: {strategy_final_return:.2f}%
            Annualized Return: {strategy_annualized_return:.2f}%
            Period: {strategy_years:.2f} years
            Total Trades: {len(df):,}
            Win Rate: {len(df[df['pnl'] > 0]) / len(df) * 100:.2f}%

            Buy and Hold Performance:
            Final Equity: ${bh_final_equity:,.2f}
            Total Return: {bh_return_pct:.2f}%
            Annualized Return: {bh_annualized_return:.2f}%
            Period: {bh_years:.2f} years
            Entry Price: ${start_price:.2f}
            Exit Price: ${end_price:.2f}

            Comparison:
            Excess Return: {excess_return:.2f}%
            Excess Annualized Return: {excess_annualized_return:.2f}%
            {'Strategy Outperforms' if excess_return > 0 else 'Buy and Hold Outperforms'}

            Risk Metrics:
            Max Drawdown: {abs(max_dd_pct):.2f}%
            MDD Window: {max_dd_start_time} → {max_dd_end_time}
        """
        ax3.text(0.1, 0.5, comparison_text, fontsize=11,
                 family='monospace', verticalalignment='center',
                 bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

        # Drawdown 圖
        ax4.fill_between(df['exit_time'], 0, df['drawdown_pct'],
                         color='crimson', alpha=0.3, step='mid')
        ax4.set_title('Drawdown (%)', fontsize=14, fontweight='bold')
        ax4.set_xlabel('Time', fontsize=12)
        ax4.set_ylabel('Drawdown (%)', fontsize=12)
        ax4.axhline(y=0, color='black', linestyle='--', alpha=0.3)
        ax4.grid(True, alpha=0.3)
        plt.setp(ax4.xaxis.get_majorticklabels(), rotation=45)

        plt.tight_layout()
        plt.show()
        
    def get_monthly_statistics(self) -> pd.DataFrame:
        """計算每月統計（勝率、盈虧等）"""
        if len(self.trades) == 0:
            print("⚠️ 沒有交易記錄")
            return pd.DataFrame()
        
        df = self.trades.copy()
        
        # 使用 exit_time 作為月份分組依據（因為盈虧在出場時實現）
        df['exit_time'] = pd.to_datetime(df['exit_time'])
        df['year_month'] = df['exit_time'].dt.to_period('M')
        
        # 按月分組統計
        monthly_stats = df.groupby('year_month').agg({
            'pnl': ['sum', 'count'],
            'return_pct': 'mean'
        }).reset_index()
        
        # 重新命名欄位
        monthly_stats.columns = ['year_month', 'total_pnl', 'trade_count', 'avg_return_pct']
        
        # 計算每月勝率
        monthly_win_rate = df.groupby('year_month').apply(
            lambda x: (x['pnl'] > 0).sum() / len(x) * 100 if len(x) > 0 else 0
        ).reset_index(name='win_rate_pct')
        
        # 合併統計
        monthly_stats = monthly_stats.merge(monthly_win_rate, on='year_month', how='left')
        
        # 計算每月賺錢/虧錢
        monthly_stats['is_profitable'] = monthly_stats['total_pnl'] > 0
        
        # 轉換 year_month 為字串格式（用於顯示）
        monthly_stats['month_str'] = monthly_stats['year_month'].astype(str)
        
        return monthly_stats
    
    def print_monthly_summary(self):
        """印出每月統計摘要"""
        if len(self.trades) == 0:
            print("⚠️ 沒有交易記錄")
            return
        
        monthly_stats = self.get_monthly_statistics()
        
        if len(monthly_stats) == 0:
            print("⚠️ 無法計算每月統計")
            return
        
        # 計算總體統計
        total_months = len(monthly_stats)
        profitable_months = monthly_stats['is_profitable'].sum()
        losing_months = total_months - profitable_months
        
        print("=" * 60)
        print("📊 每月統計摘要")
        print("=" * 60)
        print(f"總月份數: {total_months}")
        print(f"賺錢月份: {profitable_months} ({profitable_months/total_months*100:.2f}%)")
        print(f"虧錢月份: {losing_months} ({losing_months/total_months*100:.2f}%)")
        print("=" * 60)
        print("\n每月詳細統計:")
        print("-" * 60)
        
        for _, row in monthly_stats.iterrows():
            month_str = row['month_str']
            total_pnl = row['total_pnl']
            trade_count = int(row['trade_count'])
            win_rate = row['win_rate_pct']
            status = "Profit" if row['is_profitable'] else "Loss"
            
            print(f"{month_str}: {status:6s} | PnL: ${total_pnl:>10,.2f} | "
                  f"Trades: {trade_count:>4d} | Win Rate: {win_rate:>6.2f}%")
        
        print("=" * 60)
    
    def plot_monthly_pnl(self):
        """繪製每月盈虧柱狀圖"""
        import matplotlib.pyplot as plt
        
        if len(self.trades) == 0:
            print("⚠️ 沒有交易記錄")
            return
        
        monthly_stats = self.get_monthly_statistics()
        
        if len(monthly_stats) == 0:
            print("⚠️ 無法計算每月統計")
            return
        
        # 準備數據
        months = monthly_stats['month_str'].values
        pnl_values = monthly_stats['total_pnl'].values
        
        # 區分賺錢和虧錢的月份
        profitable_mask = monthly_stats['is_profitable'].values
        profitable_pnl = np.where(profitable_mask, pnl_values, 0)
        losing_pnl = np.where(~profitable_mask, pnl_values, 0)
        
        # 繪製圖表
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))
        
        # ============================================
        # 上圖：每月盈虧柱狀圖（分顏色）
        # ============================================
        x_pos = np.arange(len(months))
        width = 0.6
        
        # 賺錢的月份用綠色，虧錢的月份用紅色
        bars1 = ax1.bar(x_pos, profitable_pnl, width, 
                       color='green', alpha=0.7, label='Profitable Months')
        bars2 = ax1.bar(x_pos, losing_pnl, width,
                       color='red', alpha=0.7, label='Losing Months')
        
        ax1.axhline(y=0, color='black', linestyle='-', linewidth=0.8)
        ax1.set_xlabel('Month', fontsize=12)
        ax1.set_ylabel('PnL ($)', fontsize=12)
        ax1.set_title('Monthly Profit and Loss', fontsize=14, fontweight='bold')
        ax1.set_xticks(x_pos)
        ax1.set_xticklabels(months, rotation=45, ha='right')
        ax1.legend(loc='best')
        ax1.grid(True, alpha=0.3, axis='y')
        
        # 在柱狀圖上標註數值
        for i, (prof, loss) in enumerate(zip(profitable_pnl, losing_pnl)):
            if prof != 0:
                ax1.text(i, prof, f'${prof:,.0f}', 
                        ha='center', va='bottom' if prof > 0 else 'top', 
                        fontsize=8, fontweight='bold')
            if loss != 0:
                ax1.text(i, loss, f'${loss:,.0f}', 
                        ha='center', va='top' if loss < 0 else 'bottom', 
                        fontsize=8, fontweight='bold')
        
        # ============================================
        # 下圖：每月勝率
        # ============================================
        win_rates = monthly_stats['win_rate_pct'].values
        colors = ['green' if pnl > 0 else 'red' for pnl in pnl_values]
        
        bars3 = ax2.bar(x_pos, win_rates, width, color=colors, alpha=0.7)
        ax2.axhline(y=50, color='gray', linestyle='--', alpha=0.5, label='50% Win Rate')
        ax2.set_xlabel('Month', fontsize=12)
        ax2.set_ylabel('Win Rate (%)', fontsize=12)
        ax2.set_title('Monthly Win Rate', fontsize=14, fontweight='bold')
        ax2.set_xticks(x_pos)
        ax2.set_xticklabels(months, rotation=45, ha='right')
        ax2.set_ylim([0, 105])
        ax2.legend(loc='best')
        ax2.grid(True, alpha=0.3, axis='y')
        
        # 在柱狀圖上標註數值
        for i, (wr, pnl) in enumerate(zip(win_rates, pnl_values)):
            ax2.text(i, wr, f'{wr:.1f}%', 
                    ha='center', va='bottom', 
                    fontsize=8, fontweight='bold')
        
        # 添加總體統計文字
        total_months = len(monthly_stats)
        profitable_months = monthly_stats['is_profitable'].sum()
        losing_months = total_months - profitable_months
        
        stats_text = f"Total Months: {total_months} | "
        stats_text += f"Profitable: {profitable_months} ({profitable_months/total_months*100:.1f}%) | "
        stats_text += f"Losing: {losing_months} ({losing_months/total_months*100:.1f}%)"
        
        fig.suptitle(stats_text, fontsize=11, y=0.995)
        
        plt.tight_layout()
        plt.show()

# %% [markdown]
# 策略代碼

# %%
# =====================================================
# 2️⃣ L1-OLD 策略 Class
# =====================================================
class L1Strategy:
    """L1-OLD 突破策略"""
    
    def __init__(self, entry_param: float = 0.5, rolling_window: int = 460):
        """
        Parameters:
        -----------
        entry_param : float
            突破參數（預設 0.5）
        rolling_window : int
            計算 HL115 和突破價的滾動窗口（預設 460）
        """
        self.entry_param = entry_param
        self.rolling_window = rolling_window
        self.signals = None
        
    def calculate_indicators(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        計算策略指標
        
        Parameters:
        -----------
        df : pd.DataFrame
            需包含 'High', 'Low', 'Open', 'Close' 欄位
            
        Returns:
        --------
        df : pd.DataFrame
            新增 'HL115', '突破signal價', 'signal', 'side' 欄位
        """
        df = df.copy()
        
        # 計算 HL115（過去N根K線的價格範圍）
        df['HL115'] = (
            df['High'].shift(1).rolling(self.rolling_window, 
                                           min_periods=self.rolling_window).max() - 
            df['Low'].shift(1).rolling(self.rolling_window, 
                                         min_periods=self.rolling_window).min()
        )
        df['HL115%'] = df['HL115'] / df['Low'].shift(self.rolling_window+1)
        
        # 計算突破signal價
        df['突破signal價'] = (
            df['Low'].shift(1).rolling(self.rolling_window).min() + 
            (self.entry_param * df['HL115'])
        )
        df['突破signal價%'] = df['突破signal價']/df['Open']
        
        # 生成突破信號
        df['signal'] = False
        df['signal'] = (
            (df['signal'].shift(1) == False) & 
            (df['High'] > df['突破signal價']) & 
            (df['Open'] < df['突破signal價'])
        )
        
        # 轉換為 side（做多方向）
        df['side'] = np.nan
        df.loc[df['signal'] == True, 'side'] = 1.0
        df['side'] = df['side'].ffill()
        
        self.signals = df
        
        # 統計資訊
        total_bars = len(df)
        signal_count = df['signal'].sum()
        signal_rate = signal_count / total_bars if total_bars > 0 else 0
        
        print("=" * 60)
        print("📊 L1-OLD 策略統計")
        print("=" * 60)
        print(f"總 K 線數 (Bars): {total_bars:,}")
        print(f"信號數量 (Signals): {signal_count:,}")
        print(f"信號比例: {signal_rate:.4%}")
        print(f"策略參數: entry_param={self.entry_param}, rolling_window={self.rolling_window}")
        print("=" * 60)
        
        return df
    
    def get_signal_events(self) -> pd.DatetimeIndex:
        """取得信號發生的時間點"""
        if self.signals is None:
            print("⚠️ 請先執行 calculate_indicators()")
            return None
        
        return self.signals[self.signals['signal'] == True].index
    
    def get_signal_stats(self) -> dict:
        """取得信號統計資訊"""
        if self.signals is None:
            return None
        
        signal_count = self.signals['signal'].sum()
        total_bars = len(self.signals)
        
        return {
            'total_signals': signal_count,
            'signal_rate': signal_count / total_bars,
            'avg_HL115': self.signals['HL115'].mean(),
            'avg_price_to_signal': (self.signals['Close'] / self.signals['突破signal價']).mean()
        }
    
    def plot_strategy(self, start_idx: Optional[int] = None, end_idx: Optional[int] = None):
        """
        繪製策略圖
        
        Parameters:
        -----------
        start_idx : int, optional
            起始索引
        end_idx : int, optional
            結束索引
        """
        import matplotlib.pyplot as plt
        
        if self.signals is None:
            print("⚠️ 請先執行 calculate_indicators()")
            return
        
        df = self.signals.iloc[start_idx:end_idx] if start_idx or end_idx else self.signals
        signal_events = df[df['signal'] == True].index
        
        fig, axes = plt.subplots(2, 1, figsize=(15, 10))
        
        # 1. 價格與突破信號
        axes[0].plot(df.index, df['Close'], label='Close Price', alpha=0.7, linewidth=1)
        axes[0].plot(df.index, df['突破signal價'], label='Breakout Signal', 
                    linestyle='--', alpha=0.7, color='orange')
        axes[0].scatter(signal_events, df.loc[signal_events, 'Close'], 
                       color='red', s=50, label='Entry Signal', zorder=5, marker='^')
        axes[0].set_title(f'L1-OLD Strategy (entry_param={self.entry_param})', fontsize=12)
        axes[0].legend()
        axes[0].grid(True, alpha=0.3)
        
        # 2. HL115 波動指標
        axes[1].plot(df.index, df['HL115'], label='HL115', color='orange', linewidth=1)
        axes[1].set_title(f'Price Range Indicator (window={self.rolling_window})', fontsize=12)
        axes[1].legend()
        axes[1].grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## 依照策略訊號進出

# %%
# 使用範例
# 假設你已經有 nas100_raw 資料和 L1Strategy 策略

# 1. 初始化策略並計算信號
strategy = L1Strategy(entry_param=1, rolling_window=96)
df_with_signals = strategy.calculate_indicators(nas100_raw)

# 2. 初始化回測引擎（0.25%停損，32根K停利）
backtest = BacktestEngine(stop_loss_pct=0.005, take_profit_bars=32)
# backtest = BacktestEngine(stop_loss_pct=0.0025, take_profit_pct=0.0025, take_profit_bars=32)


# 3. 執行回測
results = backtest.backtest(
    df=df_with_signals[['Open', 'High', 'Low', 'Close']],
    signals=df_with_signals['signal']
)

# 4. 查看結果
print("\n前10筆交易:")
print(results.tail(10))

# 5. 查看績效摘要
backtest.print_summary()

# 6. 繪製權益曲線
backtest.plot_equity_curve()

# 7. 查看詳細績效指標
metrics = backtest.get_performance_metrics()
print("\n詳細績效指標:")
for key, value in metrics.items():
    print(f"{key}: {value}")
    
# 8. 查看每月統計摘要
backtest.print_monthly_summary()
backtest.plot_monthly_pnl()
monthly_stats = backtest.get_monthly_statistics()
# Out:
# ============================================================
# 📊 L1-OLD 策略統計
# ============================================================
# 總 K 線數 (Bars): 162,577
# 信號數量 (Signals): 8,075
# 信號比例: 4.9669%
# 策略參數: entry_param=1, rolling_window=96
# ============================================================
#
# 前10筆交易:
#               entry_time           exit_time  entry_price  exit_price  side  \
# 1440 2025-09-02 01:15:00 2025-09-02 07:45:00      3497.31  3479.82345     1
# 1441 2025-09-02 14:30:00 2025-09-02 23:30:00      3510.33  3526.44000     1
# 1442 2025-09-03 00:15:00 2025-09-03 08:15:00      3537.01  3540.98000     1
# 1443 2025-09-03 11:00:00 2025-09-03 19:00:00      3546.18  3569.54000     1
# 1444 2025-09-05 03:45:00 2025-09-05 11:45:00      3558.29  3553.20000     1
# 1445 2025-09-05 12:30:00 2025-09-05 20:30:00      3583.47  3589.87000     1
# 1446 2025-09-08 07:00:00 2025-09-08 15:00:00      3604.51  3645.52000     1
# 1447 2025-09-09 01:30:00 2025-09-09 09:30:00      3643.82  3654.16000     1
# 1448 2025-09-09 13:15:00 2025-09-09 14:00:00      3660.45  3642.14775     1
# 1449 2025-09-12 02:00:00 2025-09-12 06:15:00      3647.35  3653.16000     1
#
#           units  leverage   capital_used          pnl  return_pct  bars_held  \
# 1440  39.731730       1.0  138954.175426  -708.666295   -0.510000         26
# 1441  39.382482       1.0  138245.509131   620.627239    0.448931         32
# 1442  39.260883       1.0  138866.136371   141.979093    0.102242         32
# 1443  39.199396       1.0  139008.115463   901.797088    0.648737         32
# 1444  39.319424       1.0  139909.912551  -214.126858   -0.153046         32
# 1445  38.983384       1.0  139695.785693   235.524077    0.168598         32
# 1446  38.821174       1.0  139931.309769  1578.063213    1.127741         32
# 1447  38.835445       1.0  141509.372983   387.407569    0.273768         32
# 1448  38.764846       1.0  141896.780552  -723.673581   -0.510000          3
# 1449  38.705665       1.0  141173.106971   224.879913    0.159294         17
#
#                 exit_reason  stop_loss_price  take_profit_price   equity_after
# 1440              Stop Loss       3479.82345           5245.965  138245.509131
# 1441  Take Profit (32 bars)       3492.77835           5265.495  138866.136371
# 1442  Take Profit (32 bars)       3519.32495           5305.515  139008.115463
# 1443  Take Profit (32 bars)       3528.44910           5319.270  139909.912551
# 1444  Take Profit (32 bars)       3540.49855           5337.435  139695.785693
# 1445  Take Profit (32 bars)       3565.55265           5375.205  139931.309769
# 1446  Take Profit (32 bars)       3586.48745           5406.765  141509.372983
# 1447  Take Profit (32 bars)       3625.60090           5465.730  141896.780552
# 1448              Stop Loss       3642.14775           5490.675  141173.106971
# 1449            End of Data       3629.11325           5471.025  141397.986884
# ============================================================
# 📊 回測結果摘要（含動態槓桿調整 + 百分比停利）
# ============================================================
# 初始資金: $100,000.00
# 最終總equity: $141,397.99
# 總盈虧: $41,397.99
# 總報酬率: 41.40%
# 總交易次數: 1,450
# 獲利交易: 678
# 虧損交易: 772
# 勝率: 46.76%
# 平均報酬率: 0.03%
# 平均獲利: 0.46% ($492.25)
# 平均虧損: -0.35% ($-378.69)
# 獲利因子: 1.14
# 停損次數: 403
# 百分比停利次數 (0.25%): 0
#   0.25%停利賺錢出場: 0
#   0.25%停利虧錢出場: 0
# 時間停利次數 (32根K): 1,046
#   32根K後賺錢出場: 677
#   32根K後虧錢出場: 369
# 槓桿分布:
#   0.5x槓桿: 0
#   1.0x槓桿: 1,450
#   2.0x槓桿: 0
# ============================================================
# 詳細績效指標:
# Initial Capital: 100000
# Final Equity: 141397.98688398543
# Total PnL: 41397.98688398543
# Total Return (%): 41.39798688398543
# Total Trades: 1450
# Winning Trades: 678
# Losing Trades: 772
# Win Rate (%): 46.758620689655174
# Average Return (%): 0.02522139382926154
# Average Win (%): 0.45635158936497916
# Average Loss (%): -0.3534136742707599
# Average Win Amount: 492.25297936074884
# Average Loss Amount: -378.6911050810911
# Profit Factor: 1.141604422766854
# Stop Loss Count: 403
# Take Profit Pct Count: 0
# Take Profit Pct Win Count: 0
# Take Profit Pct Loss Count: 0
# Take Profit Bars Count: 1046
# Take Profit Bars Win Count: 677
# Take Profit Bars Loss Count: 369
# Leverage 0.5x Count: 0
# Leverage 1.0x Count: 1450
# Leverage 2.0x Count: 0
# ============================================================
# 📊 每月統計摘要
# ============================================================
# 總月份數: 83
# 賺錢月份: 45 (54.22%)
# 虧錢月份: 38 (45.78%)
# ============================================================
#
# 每月詳細統計:
# ------------------------------------------------------------
# 2018-11: Loss   | PnL: $ -1,699.20 | Trades:   11 | Win Rate:  27.27%
# 2018-12: Loss   | PnL: $   -235.77 | Trades:   22 | Win Rate:  36.36%
# 2019-01: Loss   | PnL: $   -102.28 | Trades:   22 | Win Rate:  50.00%
# 2019-02: Profit | PnL: $    637.28 | Trades:   13 | Win Rate:  53.85%
# 2019-03: Profit | PnL: $    111.15 | Trades:   17 | Win Rate:  52.94%
# 2019-04: Loss   | PnL: $   -876.89 | Trades:   14 | Win Rate:  50.00%
# 2019-05: Profit | PnL: $  1,001.75 | Trades:   18 | Win Rate:  50.00%
# 2019-06: Profit | PnL: $  3,583.59 | Trades:   17 | Win Rate:  64.71%
# 2019-07: Profit | PnL: $  2,193.12 | Trades:   14 | Win Rate:  50.00%
# 2019-08: Loss   | PnL: $ -2,321.64 | Trades:   21 | Win Rate:  38.10%
# 2019-09: Loss   | PnL: $   -635.45 | Trades:   13 | Win Rate:  38.46%
# 2019-10: Profit | PnL: $    186.62 | Trades:   19 | Win Rate:  52.63%
# 2019-11: Loss   | PnL: $ -1,203.48 | Trades:   13 | Win Rate:  38.46%
# 2019-12: Profit | PnL: $    664.86 | Trades:   21 | Win Rate:  33.33%
# 2020-01: Profit | PnL: $  4,350.75 | Trades:   18 | Win Rate:  55.56%
# 2020-02: Loss   | PnL: $   -699.24 | Trades:   22 | Win Rate:  50.00%
# 2020-03: Loss   | PnL: $ -2,439.38 | Trades:   24 | Win Rate:  20.83%
# 2020-04: Profit | PnL: $  2,802.91 | Trades:   20 | Win Rate:  40.00%
# 2020-05: Loss   | PnL: $ -1,202.56 | Trades:   19 | Win Rate:  42.11%
# 2020-06: Loss   | PnL: $   -808.43 | Trades:   20 | Win Rate:  50.00%
# 2020-07: Profit | PnL: $  1,778.60 | Trades:   22 | Win Rate:  54.55%
# 2020-08: Profit | PnL: $  5,037.13 | Trades:   16 | Win Rate:  56.25%
# 2020-09: Loss   | PnL: $ -3,505.21 | Trades:   18 | Win Rate:  27.78%
# 2020-10: Loss   | PnL: $ -1,957.22 | Trades:   18 | Win Rate:  38.89%
# 2020-11: Loss   | PnL: $ -2,478.63 | Trades:   15 | Win Rate:  33.33%
# 2020-12: Profit | PnL: $  3,140.78 | Trades:   21 | Win Rate:  61.90%
# 2021-01: Loss   | PnL: $   -495.32 | Trades:   16 | Win Rate:  43.75%
# 2021-02: Loss   | PnL: $   -103.20 | Trades:    8 | Win Rate:  62.50%
# 2021-03: Loss   | PnL: $ -1,368.39 | Trades:   17 | Win Rate:  29.41%
# 2021-04: Profit | PnL: $  1,415.71 | Trades:   19 | Win Rate:  47.37%
# 2021-05: Profit | PnL: $    972.07 | Trades:   25 | Win Rate:  52.00%
# 2021-06: Loss   | PnL: $ -2,970.77 | Trades:   14 | Win Rate:  28.57%
# 2021-07: Loss   | PnL: $ -1,855.39 | Trades:   21 | Win Rate:  28.57%
# 2021-08: Profit | PnL: $  1,237.34 | Trades:   17 | Win Rate:  52.94%
# 2021-09: Profit | PnL: $    279.58 | Trades:   11 | Win Rate:  45.45%
# 2021-10: Loss   | PnL: $ -1,255.90 | Trades:   19 | Win Rate:  47.37%
# 2021-11: Loss   | PnL: $ -2,680.87 | Trades:   20 | Win Rate:  35.00%
# 2021-12: Profit | PnL: $  1,639.84 | Trades:   22 | Win Rate:  54.55%
# 2022-01: Loss   | PnL: $   -854.61 | Trades:   19 | Win Rate:  42.11%
# 2022-02: Profit | PnL: $  1,660.35 | Trades:   24 | Win Rate:  58.33%
# 2022-03: Profit | PnL: $  2,926.42 | Trades:   19 | Win Rate:  73.68%
# 2022-04: Loss   | PnL: $ -2,209.31 | Trades:   16 | Win Rate:  37.50%
# 2022-05: Loss   | PnL: $ -1,922.24 | Trades:   17 | Win Rate:  29.41%
# 2022-06: Loss   | PnL: $ -1,873.04 | Trades:   16 | Win Rate:  31.25%
# 2022-07: Profit | PnL: $  2,152.40 | Trades:   11 | Win Rate:  63.64%
# 2022-08: Loss   | PnL: $ -2,282.59 | Trades:   16 | Win Rate:  25.00%
# 2022-09: Loss   | PnL: $   -987.38 | Trades:   12 | Win Rate:  33.33%
# 2022-10: Profit | PnL: $    788.77 | Trades:   12 | Win Rate:  41.67%
# 2022-11: Profit | PnL: $    537.65 | Trades:   20 | Win Rate:  40.00%
# 2022-12: Profit | PnL: $  3,190.10 | Trades:   21 | Win Rate:  61.90%
# 2023-01: Profit | PnL: $    297.43 | Trades:   17 | Win Rate:  47.06%
# 2023-02: Loss   | PnL: $ -3,859.05 | Trades:   14 | Win Rate:  21.43%
# 2023-03: Profit | PnL: $  6,183.08 | Trades:   21 | Win Rate:  71.43%
# 2023-04: Profit | PnL: $    869.58 | Trades:   14 | Win Rate:  35.71%
# 2023-05: Profit | PnL: $  2,014.10 | Trades:   13 | Win Rate:  53.85%
# 2023-06: Loss   | PnL: $ -2,889.84 | Trades:   14 | Win Rate:  35.71%
# 2023-07: Profit | PnL: $    944.87 | Trades:   18 | Win Rate:  55.56%
# 2023-08: Loss   | PnL: $   -778.18 | Trades:   11 | Win Rate:  36.36%
# 2023-09: Loss   | PnL: $ -2,945.15 | Trades:   13 | Win Rate:  30.77%
# 2023-10: Profit | PnL: $  2,718.39 | Trades:   19 | Win Rate:  47.37%
# 2023-11: Profit | PnL: $    937.19 | Trades:   13 | Win Rate:  61.54%
# 2023-12: Profit | PnL: $  3,387.79 | Trades:   13 | Win Rate:  53.85%
# 2024-01: Loss   | PnL: $ -2,978.82 | Trades:   15 | Win Rate:  26.67%
# 2024-02: Loss   | PnL: $   -970.35 | Trades:   15 | Win Rate:  40.00%
# 2024-03: Profit | PnL: $  3,483.76 | Trades:   16 | Win Rate:  56.25%
# 2024-04: Profit | PnL: $  1,179.45 | Trades:   20 | Win Rate:  35.00%
# 2024-05: Profit | PnL: $    827.07 | Trades:   21 | Win Rate:  47.62%
# 2024-06: Loss   | PnL: $   -454.83 | Trades:   17 | Win Rate:  47.06%
# 2024-07: Profit | PnL: $  4,074.35 | Trades:   20 | Win Rate:  65.00%
# 2024-08: Loss   | PnL: $   -304.46 | Trades:   19 | Win Rate:  36.84%
# 2024-09: Profit | PnL: $  2,040.64 | Trades:   19 | Win Rate:  52.63%
# 2024-10: Profit | PnL: $  1,588.35 | Trades:   23 | Win Rate:  60.87%
# 2024-11: Profit | PnL: $  1,687.82 | Trades:   17 | Win Rate:  58.82%
# 2024-12: Loss   | PnL: $   -886.10 | Trades:   13 | Win Rate:  38.46%
# 2025-01: Profit | PnL: $  5,449.68 | Trades:   26 | Win Rate:  65.38%
# 2025-02: Loss   | PnL: $ -1,509.21 | Trades:   20 | Win Rate:  50.00%
# 2025-03: Profit | PnL: $  2,740.31 | Trades:   25 | Win Rate:  56.00%
# 2025-04: Profit | PnL: $  8,703.75 | Trades:   22 | Win Rate:  59.09%
# 2025-05: Profit | PnL: $  6,773.10 | Trades:   17 | Win Rate:  64.71%
# 2025-06: Loss   | PnL: $ -3,138.55 | Trades:   17 | Win Rate:  35.29%
# 2025-07: Profit | PnL: $  1,367.99 | Trades:   19 | Win Rate:  47.37%
# 2025-08: Profit | PnL: $    667.60 | Trades:   18 | Win Rate:  44.44%
# 2025-09: Profit | PnL: $  2,911.85 | Trades:   11 | Win Rate:  72.73%
# ============================================================

# %%
# 使用範例
# 假設你已經有 nas100_raw 資料和 L1Strategy 策略

# 1. 初始化策略並計算信號
strategy = L1Strategy(entry_param=1, rolling_window=96)
df_with_signals = strategy.calculate_indicators(nas100_raw)

# 2. 初始化回測引擎（0.25%停損，32根K停利）
backtest = BacktestEngine(stop_loss_pct=0.005, take_profit_pct=0.0025, take_profit_bars=32)
# backtest = BacktestEngine(stop_loss_pct=0.0025, take_profit_pct=0.0025, take_profit_bars=32)


# 3. 執行回測
results = backtest.backtest(
    df=df_with_signals[['Open', 'High', 'Low', 'Close']],
    signals=df_with_signals['signal']
)

# 4. 查看結果
print("\n前10筆交易:")
print(results.head(10))

# 5. 查看績效摘要
backtest.print_summary()

# 6. 繪製權益曲線
backtest.plot_equity_curve()

# 7. 查看詳細績效指標
metrics = backtest.get_performance_metrics()
print("\n詳細績效指標:")
for key, value in metrics.items():
    print(f"{key}: {value}")
    
# 8. 查看每月統計摘要
backtest.print_monthly_summary()
backtest.plot_monthly_pnl()
monthly_stats = backtest.get_monthly_statistics()
# Out:
# ============================================================
# 📊 L1-OLD 策略統計
# ============================================================
# 總 K 線數 (Bars): 162,577
# 信號數量 (Signals): 8,075
# 信號比例: 4.9669%
# 策略參數: entry_param=1, rolling_window=96
# ============================================================
#
# 前10筆交易:
#            entry_time           exit_time  entry_price  exit_price  side  \
# 0 2018-11-06 09:00:00 2018-11-06 15:45:00      1234.55  1228.37725     1
# 1 2018-11-07 11:30:00 2018-11-07 14:00:00      1234.25  1228.07875     1
# 2 2018-11-14 17:45:00 2018-11-14 18:30:00      1208.26  1214.30130     1
# 3 2018-11-14 19:00:00 2018-11-14 19:15:00      1216.08  1209.99960     1
# 4 2018-11-16 01:15:00 2018-11-16 09:15:00      1215.72  1216.65000     1
# 5 2018-11-16 13:30:00 2018-11-16 21:30:00      1221.72  1221.34000     1
# 6 2018-11-19 17:45:00 2018-11-20 02:45:00      1223.80  1221.85000     1
# 7 2018-11-20 07:15:00 2018-11-20 15:15:00      1224.79  1221.95000     1
# 8 2018-11-21 15:15:00 2018-11-22 00:15:00      1229.37  1225.96000     1
# 9 2018-11-28 17:00:00 2018-11-29 02:00:00      1223.87  1222.54000     1
#
#        units  leverage   capital_used         pnl  return_pct  bars_held  \
# 0  81.001175       1.0  100000.000000 -510.000000   -0.510000         27
# 1  80.607656       1.0   99490.000000 -507.399000   -0.510000         10
# 2  81.921607       1.0   98982.601000  485.014745    0.490000          3
# 3  81.793645       1.0   99467.615745 -507.284840   -0.510000          1
# 4  81.400595       1.0   98960.330905   65.806520    0.066498         32
# 5  81.054691       1.0   99026.137425  -40.703396   -0.041104         32
# 6  80.883669       1.0   98985.434028 -167.621698   -0.169340         32
# 7  80.681433       1.0   98817.812330 -239.017051   -0.241876         32
# 8  80.186433       1.0   98578.795279 -283.293616   -0.287378         32
# 9  80.315313       1.0   98295.501663 -116.648916   -0.118672         32
#
#              exit_reason  stop_loss_price  take_profit_price  equity_after
# 0              Stop Loss       1228.37725         1240.72275  99490.000000
# 1              Stop Loss       1228.07875         1240.42125  98982.601000
# 2    Take Profit (0.25%)       1202.21870         1214.30130  99467.615745
# 3              Stop Loss       1209.99960         1222.16040  98960.330905
# 4  Take Profit (32 bars)       1209.64140         1221.79860  99026.137425
# 5  Take Profit (32 bars)       1215.61140         1227.82860  98985.434028
# 6  Take Profit (32 bars)       1217.68100         1229.91900  98817.812330
# 7  Take Profit (32 bars)       1218.66605         1230.91395  98578.795279
# 8  Take Profit (32 bars)       1223.22315         1235.51685  98295.501663
# 9  Take Profit (32 bars)       1217.75065         1229.98935  98178.852747
# ============================================================
# 📊 回測結果摘要（含動態槓桿調整 + 百分比停利）
# ============================================================
# 初始資金: $100,000.00
# 最終總equity: $110,119.81
# 總盈虧: $10,119.81
# 總報酬率: 10.12%
# 總交易次數: 1,819
# 獲利交易: 908
# 虧損交易: 911
# 勝率: 49.92%
# 平均報酬率: 0.01%
# 平均獲利: 0.37% ($358.20)
# 平均虧損: -0.36% ($-345.91)
# 獲利因子: 1.03
# 停損次數: 492
# 百分比停利次數 (0.25%): 572
#   0.25%停利賺錢出場: 572
#   0.25%停利虧錢出場: 0
# 時間停利次數 (32根K): 754
#   32根K後賺錢出場: 335
#   32根K後虧錢出場: 419
# 槓桿分布:
#   0.5x槓桿: 0
#   1.0x槓桿: 1,819
#   2.0x槓桿: 0
# ============================================================
# 詳細績效指標:
# Initial Capital: 100000
# Final Equity: 110119.80777944453
# Total PnL: 10119.807779444873
# Total Return (%): 10.119807779444526
# Total Trades: 1819
# Winning Trades: 908
# Losing Trades: 911
# Win Rate (%): 49.91753710830126
# Average Return (%): 0.006124020176751375
# Average Win (%): 0.3712358402483587
# Average Loss (%): -0.35778545581119536
# Average Win Amount: 358.202996089345
# Average Loss Amount: -345.9149425572781
# Profit Factor: 1.0321132724351496
# Stop Loss Count: 492
# Take Profit Pct Count: 572
# Take Profit Pct Win Count: 572
# Take Profit Pct Loss Count: 0
# Take Profit Bars Count: 754
# Take Profit Bars Win Count: 335
# Take Profit Bars Loss Count: 419
# Leverage 0.5x Count: 0
# Leverage 1.0x Count: 1819
# Leverage 2.0x Count: 0
# ============================================================
# 📊 每月統計摘要
# ============================================================
# 總月份數: 83
# 賺錢月份: 46 (55.42%)
# 虧錢月份: 37 (44.58%)
# ============================================================
#
# 每月詳細統計:
# ------------------------------------------------------------
# 2018-11: Loss   | PnL: $ -1,860.96 | Trades:   12 | Win Rate:  25.00%
# 2018-12: Profit | PnL: $    509.20 | Trades:   24 | Win Rate:  45.83%
# 2019-01: Loss   | PnL: $    -75.09 | Trades:   23 | Win Rate:  52.17%
# 2019-02: Profit | PnL: $    415.97 | Trades:   13 | Win Rate:  61.54%
# 2019-03: Profit | PnL: $    389.70 | Trades:   17 | Win Rate:  52.94%
# 2019-04: Loss   | PnL: $   -882.82 | Trades:   14 | Win Rate:  50.00%
# 2019-05: Profit | PnL: $    901.22 | Trades:   20 | Win Rate:  60.00%
# 2019-06: Profit | PnL: $  4,668.90 | Trades:   24 | Win Rate:  66.67%
# 2019-07: Profit | PnL: $  1,695.80 | Trades:   21 | Win Rate:  61.90%
# 2019-08: Loss   | PnL: $ -2,217.83 | Trades:   29 | Win Rate:  48.28%
# 2019-09: Loss   | PnL: $ -2,036.19 | Trades:   17 | Win Rate:  35.29%
# 2019-10: Profit | PnL: $    388.20 | Trades:   23 | Win Rate:  52.17%
# 2019-11: Loss   | PnL: $ -1,204.12 | Trades:   13 | Win Rate:  38.46%
# 2019-12: Profit | PnL: $  1,352.86 | Trades:   23 | Win Rate:  39.13%
# 2020-01: Profit | PnL: $  1,094.67 | Trades:   21 | Win Rate:  52.38%
# 2020-02: Loss   | PnL: $   -720.39 | Trades:   24 | Win Rate:  50.00%
# 2020-03: Loss   | PnL: $ -3,560.55 | Trades:   42 | Win Rate:  42.86%
# 2020-04: Profit | PnL: $  1,856.54 | Trades:   36 | Win Rate:  52.78%
# 2020-05: Loss   | PnL: $   -725.03 | Trades:   22 | Win Rate:  45.45%
# 2020-06: Loss   | PnL: $ -2,192.40 | Trades:   23 | Win Rate:  34.78%
# 2020-07: Profit | PnL: $    982.31 | Trades:   35 | Win Rate:  54.29%
# 2020-08: Profit | PnL: $  1,941.52 | Trades:   29 | Win Rate:  58.62%
# 2020-09: Loss   | PnL: $ -3,113.18 | Trades:   20 | Win Rate:  40.00%
# 2020-10: Loss   | PnL: $ -1,967.01 | Trades:   21 | Win Rate:  42.86%
# 2020-11: Loss   | PnL: $ -1,637.59 | Trades:   17 | Win Rate:  41.18%
# 2020-12: Profit | PnL: $  2,599.55 | Trades:   31 | Win Rate:  54.84%
# 2021-01: Loss   | PnL: $   -823.04 | Trades:   20 | Win Rate:  50.00%
# 2021-02: Profit | PnL: $    122.04 | Trades:    9 | Win Rate:  55.56%
# 2021-03: Loss   | PnL: $ -1,505.51 | Trades:   20 | Win Rate:  35.00%
# 2021-04: Loss   | PnL: $   -392.79 | Trades:   25 | Win Rate:  40.00%
# 2021-05: Profit | PnL: $  1,203.02 | Trades:   29 | Win Rate:  51.72%
# 2021-06: Loss   | PnL: $ -1,891.68 | Trades:   15 | Win Rate:  33.33%
# 2021-07: Loss   | PnL: $   -930.34 | Trades:   25 | Win Rate:  36.00%
# 2021-08: Profit | PnL: $  1,638.95 | Trades:   20 | Win Rate:  65.00%
# 2021-09: Loss   | PnL: $   -163.55 | Trades:   15 | Win Rate:  40.00%
# 2021-10: Loss   | PnL: $   -855.01 | Trades:   21 | Win Rate:  52.38%
# 2021-11: Loss   | PnL: $ -1,651.25 | Trades:   22 | Win Rate:  40.91%
# 2021-12: Profit | PnL: $  1,718.66 | Trades:   23 | Win Rate:  56.52%
# 2022-01: Loss   | PnL: $ -1,062.45 | Trades:   20 | Win Rate:  45.00%
# 2022-02: Profit | PnL: $  1,289.23 | Trades:   30 | Win Rate:  63.33%
# 2022-03: Profit | PnL: $    526.26 | Trades:   28 | Win Rate:  57.14%
# 2022-04: Loss   | PnL: $ -1,526.74 | Trades:   18 | Win Rate:  38.89%
# 2022-05: Loss   | PnL: $ -2,759.82 | Trades:   21 | Win Rate:  28.57%
# 2022-06: Loss   | PnL: $ -2,573.78 | Trades:   20 | Win Rate:  35.00%
# 2022-07: Profit | PnL: $  2,383.76 | Trades:   14 | Win Rate:  78.57%
# 2022-08: Loss   | PnL: $ -1,355.10 | Trades:   17 | Win Rate:  29.41%
# 2022-09: Profit | PnL: $     61.09 | Trades:   15 | Win Rate:  46.67%
# 2022-10: Profit | PnL: $     38.24 | Trades:   18 | Win Rate:  50.00%
# 2022-11: Profit | PnL: $    784.46 | Trades:   26 | Win Rate:  50.00%
# 2022-12: Profit | PnL: $    874.98 | Trades:   25 | Win Rate:  56.00%
# 2023-01: Profit | PnL: $  1,205.45 | Trades:   23 | Win Rate:  56.52%
# 2023-02: Loss   | PnL: $ -3,627.44 | Trades:   15 | Win Rate:  20.00%
# 2023-03: Profit | PnL: $  3,295.45 | Trades:   34 | Win Rate:  61.76%
# 2023-04: Loss   | PnL: $ -1,412.41 | Trades:   19 | Win Rate:  36.84%
# 2023-05: Profit | PnL: $    534.64 | Trades:   18 | Win Rate:  55.56%
# 2023-06: Loss   | PnL: $ -2,041.76 | Trades:   14 | Win Rate:  35.71%
# 2023-07: Profit | PnL: $     29.52 | Trades:   22 | Win Rate:  45.45%
# 2023-08: Loss   | PnL: $   -711.63 | Trades:   12 | Win Rate:  33.33%
# 2023-09: Loss   | PnL: $ -2,447.85 | Trades:   14 | Win Rate:  28.57%
# 2023-10: Profit | PnL: $  1,197.42 | Trades:   25 | Win Rate:  56.00%
# 2023-11: Profit | PnL: $    788.08 | Trades:   15 | Win Rate:  60.00%
# 2023-12: Profit | PnL: $  1,989.20 | Trades:   20 | Win Rate:  60.00%
# 2024-01: Loss   | PnL: $ -1,721.85 | Trades:   17 | Win Rate:  35.29%
# 2024-02: Loss   | PnL: $   -211.47 | Trades:   15 | Win Rate:  40.00%
# 2024-03: Profit | PnL: $  4,402.78 | Trades:   24 | Win Rate:  75.00%
# 2024-04: Profit | PnL: $  2,046.06 | Trades:   29 | Win Rate:  58.62%
# 2024-05: Profit | PnL: $     67.71 | Trades:   26 | Win Rate:  50.00%
# 2024-06: Profit | PnL: $    220.64 | Trades:   20 | Win Rate:  45.00%
# 2024-07: Profit | PnL: $  3,797.71 | Trades:   28 | Win Rate:  64.29%
# 2024-08: Loss   | PnL: $   -473.41 | Trades:   22 | Win Rate:  45.45%
# 2024-09: Profit | PnL: $  2,412.79 | Trades:   24 | Win Rate:  62.50%
# 2024-10: Profit | PnL: $    277.59 | Trades:   28 | Win Rate:  46.43%
# 2024-11: Profit | PnL: $  1,096.17 | Trades:   21 | Win Rate:  61.90%
# 2024-12: Loss   | PnL: $ -1,380.43 | Trades:   16 | Win Rate:  37.50%
# 2025-01: Profit | PnL: $  3,699.81 | Trades:   31 | Win Rate:  51.61%
# 2025-02: Loss   | PnL: $   -632.18 | Trades:   21 | Win Rate:  57.14%
# 2025-03: Profit | PnL: $  2,955.19 | Trades:   30 | Win Rate:  56.67%
# 2025-04: Profit | PnL: $  2,509.75 | Trades:   42 | Win Rate:  57.14%
# 2025-05: Profit | PnL: $  2,138.26 | Trades:   24 | Win Rate:  62.50%
# 2025-06: Loss   | PnL: $ -2,221.27 | Trades:   24 | Win Rate:  41.67%
# 2025-07: Profit | PnL: $    895.31 | Trades:   22 | Win Rate:  54.55%
# 2025-08: Profit | PnL: $    365.46 | Trades:   19 | Win Rate:  47.37%
# 2025-09: Profit | PnL: $  1,323.62 | Trades:   15 | Win Rate:  60.00%
# ============================================================

# %%
# results.tail(50)

# %% [markdown]
# ## 策略訊號 + ML篩選進場

# %% [markdown]
# 只進預測1

# %%
class L1LeverageStrategy:
    """L1 策略 + ML 預測篩選 + 槓桿調整"""

    def __init__(
        self,
        entry_param: float = 0.5,
        rolling_window: int = 460,
        ml_pred_file: str = 'Pred_xgb.csv',
        allowed_predicted_labels: Optional[Iterable[int]] = None,
        leverage_map: Optional[Dict[int, float]] = None,
    ):
        self.entry_param = entry_param
        self.rolling_window = rolling_window
        self.ml_pred_file = ml_pred_file
        self.signals = None

        # 允許的 predicted_label；None 代表不過濾
        self.allowed_predicted_labels = (
            set(allowed_predicted_labels) if allowed_predicted_labels is not None else None
        )

        # 槓桿映射預設：-1/0/1 對應 0.5x / 1.0x / 2.0x
        self.leverage_map = leverage_map or {-1: 0.5, 0: 1.0, 1: 2.0}

        self.ml_predictions = None
        self.ml_predicted_labels = None
        self.ml_start_time = None

        self._load_ml_predictions()

    def _load_ml_predictions(self):
        """載入 ML 預測檔（須含 Date 與 predicted_label 欄位）"""
        try:
            ml_df = pd.read_csv(self.ml_pred_file)

            date_col = 'Date' if 'Date' in ml_df.columns else ml_df.columns[0]
            ml_df[date_col] = pd.to_datetime(ml_df[date_col])
            ml_df.set_index(date_col, inplace=True)
            ml_df.sort_index(inplace=True)

            if 'predicted_label' not in ml_df.columns:
                raise ValueError(f"{self.ml_pred_file} 缺少 predicted_label 欄位")

            self.ml_predicted_labels = ml_df['predicted_label']
            self.ml_predictions = self.ml_predicted_labels.map(self.leverage_map).fillna(1.0)
            self.ml_start_time = self.ml_predictions.index[0]

            print(f"✅ 載入 {self.ml_pred_file}：{len(self.ml_predictions):,} 筆")
            print(f"   時間範圍：{self.ml_predictions.index[0]} ~ {self.ml_predictions.index[-1]}")
            print("   predicted_label 分布：")
            for label, count in self.ml_predicted_labels.value_counts().sort_index().items():
                print(f"     {label}: {count:,}")
        except Exception as e:
            print(f"⚠️ 載入 ML 預測失敗：{e}")
            self.ml_predictions = pd.Series(dtype=float)
            self.ml_predicted_labels = pd.Series(dtype=float)
            self.ml_start_time = None

    def calculate_indicators(self, df: pd.DataFrame) -> pd.DataFrame:
        df = df.copy()

        if self.ml_start_time is not None:
            df = df.loc[df.index >= self.ml_start_time].copy()
        else:
            print("⚠️ 尚未讀到 ML 預測資料，使用全部價格資料")

        df['HL115'] = (
            df['High'].shift(1).rolling(self.rolling_window, min_periods=self.rolling_window).max()
            - df['Low'].shift(1).rolling(self.rolling_window, min_periods=self.rolling_window).min()
        )
        df['HL115%'] = df['HL115'] / df['Low'].shift(self.rolling_window + 1)

        df['突破signal價'] = (
            df['Low'].shift(1).rolling(self.rolling_window).min() + self.entry_param * df['HL115']
        )
        df['突破signal價%'] = df['突破signal價'] / df['Open']

        df['signal'] = False
        df['signal'] = (
            (df['signal'].shift(1) == False)
            & (df['High'] > df['突破signal價'])
            & (df['Open'] < df['突破signal價'])
        )

        df['leverage'] = 1.0
        df['predicted_label'] = np.nan

        if self.ml_predictions is not None and len(self.ml_predictions) > 0:
            # 以價格索引對齊 ML 預測，若當下沒有就用之前最近一筆
            aligned_labels = self.ml_predicted_labels.reindex(df.index, method='ffill')
            aligned_leverage = aligned_labels.map(self.leverage_map).fillna(1.0)

            df['predicted_label'] = aligned_labels
            df['leverage'] = aligned_leverage

            signal_labels = df.loc[df['signal'], 'predicted_label'].dropna()
            matched = len(signal_labels)
            total_signals = int(df['signal'].sum())
            print(f"✅ L1 信號 {total_signals:,} 筆，成功匹配 {matched:,} 筆 ML 預測")
            if matched > 0:
                for label, count in signal_labels.value_counts().sort_index().items():
                    lev = self.leverage_map.get(label, 1.0)
                    print(f"   predicted_label={label}: {count:,} (leverage={lev}x)")
        else:
            print("⚠️ 無 ML 槓桿資料，全部使用 1.0x")

        if self.allowed_predicted_labels is not None:
            allowed_mask = df['predicted_label'].isin(self.allowed_predicted_labels).fillna(False)
            blocked = int(df['signal'].sum() - (df['signal'] & allowed_mask).sum())
            df['signal'] = df['signal'] & allowed_mask
            df.loc[~allowed_mask, 'leverage'] = 1.0
            print(f"🔍 ML 過濾：排除 {blocked:,} 筆不在 {sorted(self.allowed_predicted_labels)} 的信號")

        df['side'] = np.nan
        df.loc[df['signal'], 'side'] = 1.0
        df['side'] = df['side'].ffill()

        self.signals = df

        signal_df = df[df['signal']]
        leverage_counts = signal_df['leverage'].value_counts().sort_index()

        print("=" * 60)
        print("📊 L1 + ML 策略統計")
        print("=" * 60)
        print(f"總 K 線數: {len(df):,}")
        print(f"L1 信號數: {len(signal_df):,}")
        for lev, count in leverage_counts.items():
            print(f"  槓桿 {lev}x: {count:,} 筆")
        print("=" * 60)

        return df

    def get_signal_events(self) -> pd.DatetimeIndex:
        if self.signals is None:
            print("⚠️ 請先執行 calculate_indicators()")
            return None
        return self.signals.index[self.signals['signal']]

    def get_signal_stats(self) -> dict:
        if self.signals is None:
            return {}
        sig = self.signals[self.signals['signal']]
        total = len(sig)
        counts = sig['leverage'].value_counts().to_dict()
        return {
            'total_signals': total,
            'signal_rate': total / len(self.signals),
            'leverage_counts': counts,
            'avg_HL115': self.signals['HL115'].mean(),
            'avg_price_to_signal': (self.signals['Close'] / self.signals['突破signal價']).mean(),
        }

# %%
# 使用範例
# 假設你已經載入 nas100_raw (含 Open/High/Low/Close)

# === 可調整參數 ===
# dt et lightgbm lr nb rf svm xgboost
ML_PRED_FILE = r'C:\Users\a124a\OneDrive\桌面\策略開發\MetaLabelLearning\MetaNewHigh\pred_results\pred_dt_2020_2025.csv'                # 指定要使用的預測檔
ALLOWED_PRED_LABELS = {1, 0}                # 只允許 predicted_label = 1 或 0 進場
# LEVERAGE_MAP = {-1: 1, 0: 1, 1: 1}    # 需要的槓桿對應
LEVERAGE_MAP = {-1: 1, 0: 2, 1: 4} 

# 1. 初始化策略（結合 L1 + ML）
strategy = L1LeverageStrategy(
    entry_param=1,
    rolling_window=96,
    ml_pred_file=ML_PRED_FILE,
    allowed_predicted_labels=ALLOWED_PRED_LABELS,
    leverage_map=LEVERAGE_MAP
)
df_with_signals = strategy.calculate_indicators(nas100_raw)

# 2. 初始化回測引擎（例：0.25% 停損，32 根 K 停利）
# backtest = BacktestEngine(stop_loss_pct=0.0025, take_profit_bars=32)
backtest = BacktestEngine(stop_loss_pct=0.0025, take_profit_bars=32, take_profit_pct=0.0025)


# 3. 執行回測
results = backtest.backtest(
    df=df_with_signals[['Open', 'High', 'Low', 'Close']],
    signals=df_with_signals['signal'],
    leverage_series=df_with_signals['leverage']  # 傳入 ML 調整後的槓桿
)

# 4. 查看結果
print("\n前10筆交易:")
print(results.tail(10))

# 5. 查看績效摘要與圖表
backtest.print_summary()
backtest.plot_equity_curve()

# 6. 詳細指標與每月統計
metrics = backtest.get_performance_metrics()
print("\n詳細績效指標:")
for key, value in metrics.items():
    print(f"{key}: {value}")

backtest.print_monthly_summary()
backtest.plot_monthly_pnl()
monthly_stats = backtest.get_monthly_statistics()
# Out:
# ✅ 載入 C:\Users\a124a\OneDrive\桌面\策略開發\MetaLabelLearning\MetaNewHigh\pred_results\pred_dt_2020_2025.csv：4,010 筆
#    時間範圍：2020-01-29 01:30:00 ~ 2025-08-11 03:15:00
#    predicted_label 分布：
#      -1: 1,707
#      0: 645
#      1: 1,658
# ✅ L1 信號 6,776 筆，成功匹配 6,776 筆 ML 預測
#    predicted_label=-1: 2,846 (leverage=1x)
#    predicted_label=0: 1,274 (leverage=2x)
#    predicted_label=1: 2,656 (leverage=4x)
# 🔍 ML 過濾：排除 2,846 筆不在 [0, 1] 的信號
# ============================================================
# 📊 L1 + ML 策略統計
# ============================================================
# 總 K 線數: 133,421
# L1 信號數: 3,930
#   槓桿 2x: 1,274 筆
#   槓桿 4x: 2,656 筆
# ============================================================
#
# 前10筆交易:
#               entry_time           exit_time  entry_price   exit_price  side  \
# 1299 2025-06-02 11:30:00 2025-06-02 13:30:00      3356.61  3365.001525     1
# 1300 2025-06-02 13:45:00 2025-06-02 14:45:00      3370.28  3378.705700     1
# 1301 2025-06-02 16:00:00 2025-06-02 19:45:00      3372.46  3380.891150     1
# 1302 2025-06-25 07:30:00 2025-06-25 08:15:00      3335.16  3326.822100     1
# 1303 2025-08-04 13:30:00 2025-08-04 13:45:00      3375.95  3384.389875     1
# 1304 2025-08-05 14:45:00 2025-08-05 23:45:00      3385.24  3383.150000     1
# 1305 2025-08-07 02:00:00 2025-08-07 05:30:00      3381.63  3373.175925     1
# 1306 2025-08-07 06:30:00 2025-08-07 07:30:00      3385.33  3393.793325     1
# 1307 2025-08-07 07:45:00 2025-08-07 08:00:00      3396.10  3387.609750     1
# 1308 2025-08-07 19:30:00 2025-08-07 22:00:00      3399.56  3391.061100     1
#
#            units  leverage   capital_used          pnl  return_pct  bars_held  \
# 1299   91.652092         2  153820.165069   738.336792    0.480000          8
# 1300  183.436987         4  154558.501862  1483.761618    0.960000          4
# 1301  185.078267         4  156042.263480  1498.005729    0.960000         15
# 1302   94.472391         2  157540.269209  -819.209400   -0.520000          3
# 1303   92.845605         2  156721.059809   752.261087    0.480000          1
# 1304   93.035248         2  157473.320896  -225.938332   -0.143477         32
# 1305  186.001878         4  157247.382564 -1635.372779   -1.040000         14
# 1306  183.866282         4  155612.009786  1493.875294    0.960000          4
# 1307  185.042708         4  157105.885080 -1633.901205   -1.040000          1
# 1308  182.931890         4  155471.983875 -1616.908632   -1.040000          6
#
#                 exit_reason  stop_loss_price  take_profit_price   equity_after
# 1299    Take Profit (0.25%)      3348.218475        3365.001525  154558.501862
# 1300    Take Profit (0.25%)      3361.854300        3378.705700  156042.263480
# 1301    Take Profit (0.25%)      3364.028850        3380.891150  157540.269209
# 1302              Stop Loss      3326.822100        3343.497900  156721.059809
# 1303    Take Profit (0.25%)      3367.510125        3384.389875  157473.320896
# 1304  Take Profit (32 bars)      3376.776900        3393.703100  157247.382564
# 1305              Stop Loss      3373.175925        3390.084075  155612.009786
# 1306    Take Profit (0.25%)      3376.866675        3393.793325  157105.885080
# 1307              Stop Loss      3387.609750        3404.590250  155471.983875
# 1308              Stop Loss      3391.061100        3408.058900  153855.075243
# ============================================================
# 📊 回測結果摘要（含動態槓桿調整 + 百分比停利）
# ============================================================
# 初始資金: $100,000.00
# 最終總equity: $153,855.08
# 總盈虧: $53,855.08
# 總報酬率: 53.86%
# 總交易次數: 1,309
# 獲利交易: 701
# 虧損交易: 608
# 勝率: 53.55%
# 平均報酬率: 0.04%
# 平均獲利: 0.78% ($873.53)
# 平均虧損: -0.83% ($-918.57)
# 獲利因子: 1.10
# 停損次數: 558
# 百分比停利次數 (0.25%): 669
#   0.25%停利賺錢出場: 669
#   0.25%停利虧錢出場: 0
# 時間停利次數 (32根K): 82
#   32根K後賺錢出場: 32
#   32根K後虧錢出場: 50
# 槓桿分布:
#   0.5x槓桿: 0
#   1.0x槓桿: 0
#   2.0x槓桿: 420
# ============================================================
# 詳細績效指標:
# Initial Capital: 100000
# Final Equity: 153855.0752425715
# Total PnL: 53855.075242571664
# Total Return (%): 53.8550752425715
# Total Trades: 1309
# Winning Trades: 701
# Losing Trades: 608
# Win Rate (%): 53.55233002291826
# Average Return (%): 0.036520388493562636
# Average Win (%): 0.7849831112642621
# Average Loss (%): -0.8264275862798917
# Average Win Amount: 873.5301552201055
# Average Loss Amount: -918.5683611294775
# Profit Factor: 1.096429868623924
# Stop Loss Count: 558
# Take Profit Pct Count: 669
# Take Profit Pct Win Count: 669
# Take Profit Pct Loss Count: 0
# Take Profit Bars Count: 82
# Take Profit Bars Win Count: 32
# Take Profit Bars Loss Count: 50
# Leverage 0.5x Count: 0
# Leverage 1.0x Count: 0
# Leverage 2.0x Count: 420
# ============================================================
# 📊 每月統計摘要
# ============================================================
# 總月份數: 63
# 賺錢月份: 33 (52.38%)
# 虧錢月份: 30 (47.62%)
# ============================================================
#
# 每月詳細統計:
# ------------------------------------------------------------
# 2020-01: Loss   | PnL: $ -2,025.35 | Trades:    4 | Win Rate:  25.00%
# 2020-02: Profit | PnL: $  2,877.69 | Trades:   36 | Win Rate:  58.33%
# 2020-03: Loss   | PnL: $ -3,884.46 | Trades:   10 | Win Rate:  30.00%
# 2020-04: Profit | PnL: $  1,256.99 | Trades:   19 | Win Rate:  57.89%
# 2020-05: Profit | PnL: $  1,526.35 | Trades:   25 | Win Rate:  56.00%
# 2020-06: Loss   | PnL: $   -168.62 | Trades:   14 | Win Rate:  50.00%
# 2020-07: Loss   | PnL: $   -196.96 | Trades:   23 | Win Rate:  56.52%
# 2020-08: Loss   | PnL: $ -1,564.86 | Trades:   31 | Win Rate:  51.61%
# 2020-09: Profit | PnL: $    930.87 | Trades:   16 | Win Rate:  50.00%
# 2020-10: Loss   | PnL: $ -1,935.09 | Trades:   21 | Win Rate:  42.86%
# 2020-11: Loss   | PnL: $   -922.78 | Trades:   23 | Win Rate:  47.83%
# 2020-12: Profit | PnL: $  5,974.09 | Trades:   41 | Win Rate:  58.54%
# 2021-01: Loss   | PnL: $ -1,692.69 | Trades:   15 | Win Rate:  46.67%
# 2021-02: Loss   | PnL: $ -2,601.28 | Trades:   14 | Win Rate:  42.86%
# 2021-03: Profit | PnL: $  4,665.82 | Trades:   19 | Win Rate:  63.16%
# 2021-04: Profit | PnL: $  2,190.22 | Trades:    9 | Win Rate:  66.67%
# 2021-05: Profit | PnL: $  2,201.27 | Trades:   19 | Win Rate:  57.89%
# 2021-06: Loss   | PnL: $ -4,155.04 | Trades:   11 | Win Rate:  27.27%
# 2021-10: Profit | PnL: $  2,319.49 | Trades:   12 | Win Rate:  58.33%
# 2021-11: Profit | PnL: $    815.71 | Trades:    5 | Win Rate:  60.00%
# 2021-12: Profit | PnL: $  3,345.85 | Trades:   23 | Win Rate:  60.87%
# 2022-01: Loss   | PnL: $ -3,794.42 | Trades:   25 | Win Rate:  40.00%
# 2022-02: Loss   | PnL: $ -2,090.18 | Trades:   33 | Win Rate:  54.55%
# 2022-03: Profit | PnL: $  3,497.26 | Trades:   37 | Win Rate:  56.76%
# 2022-04: Loss   | PnL: $ -2,122.20 | Trades:   14 | Win Rate:  35.71%
# 2022-05: Loss   | PnL: $ -1,519.01 | Trades:   15 | Win Rate:  46.67%
# 2022-06: Loss   | PnL: $ -6,140.54 | Trades:   16 | Win Rate:  31.25%
# 2022-07: Loss   | PnL: $    -95.57 | Trades:   17 | Win Rate:  52.94%
# 2022-08: Loss   | PnL: $ -1,183.49 | Trades:   21 | Win Rate:  47.62%
# 2022-09: Profit | PnL: $    664.27 | Trades:   10 | Win Rate:  50.00%
# 2022-10: Profit | PnL: $  2,738.08 | Trades:   17 | Win Rate:  64.71%
# 2022-11: Profit | PnL: $  9,700.54 | Trades:   29 | Win Rate:  68.97%
# 2022-12: Profit | PnL: $  1,436.76 | Trades:   26 | Win Rate:  57.69%
# 2023-01: Profit | PnL: $    923.38 | Trades:   28 | Win Rate:  53.57%
# 2023-02: Loss   | PnL: $   -677.05 | Trades:    9 | Win Rate:  44.44%
# 2023-03: Profit | PnL: $  2,370.27 | Trades:   48 | Win Rate:  54.17%
# 2023-04: Loss   | PnL: $ -1,694.90 | Trades:   14 | Win Rate:  35.71%
# 2023-05: Loss   | PnL: $   -717.72 | Trades:    7 | Win Rate:  42.86%
# 2023-06: Loss   | PnL: $ -3,001.81 | Trades:   16 | Win Rate:  37.50%
# 2023-07: Profit | PnL: $  1,897.82 | Trades:   28 | Win Rate:  53.57%
# 2023-08: Loss   | PnL: $ -2,776.64 | Trades:   14 | Win Rate:  35.71%
# 2023-09: Loss   | PnL: $ -3,048.95 | Trades:   14 | Win Rate:  35.71%
# 2023-10: Loss   | PnL: $ -1,980.75 | Trades:    6 | Win Rate:  33.33%
# 2023-11: Profit | PnL: $  5,138.47 | Trades:   23 | Win Rate:  60.87%
# 2023-12: Profit | PnL: $  1,723.80 | Trades:   31 | Win Rate:  54.84%
# 2024-01: Loss   | PnL: $ -4,524.96 | Trades:    6 | Win Rate:  16.67%
# 2024-02: Loss   | PnL: $   -793.96 | Trades:   18 | Win Rate:  50.00%
# 2024-03: Profit | PnL: $  3,980.51 | Trades:   36 | Win Rate:  55.56%
# 2024-04: Profit | PnL: $  4,617.96 | Trades:   34 | Win Rate:  67.65%
# 2024-05: Loss   | PnL: $   -726.60 | Trades:    5 | Win Rate:  40.00%
# 2024-07: Profit | PnL: $  3,304.88 | Trades:   13 | Win Rate:  61.54%
# 2024-08: Profit | PnL: $    680.88 | Trades:   28 | Win Rate:  53.57%
# 2024-09: Profit | PnL: $  6,622.91 | Trades:   37 | Win Rate:  59.46%
# 2024-10: Loss   | PnL: $   -358.79 | Trades:   42 | Win Rate:  50.00%
# 2024-11: Profit | PnL: $  5,217.22 | Trades:   34 | Win Rate:  61.76%
# 2024-12: Profit | PnL: $  6,607.57 | Trades:   20 | Win Rate:  65.00%
# 2025-01: Profit | PnL: $ 12,046.77 | Trades:   27 | Win Rate:  66.67%
# 2025-02: Profit | PnL: $  5,175.66 | Trades:   37 | Win Rate:  59.46%
# 2025-03: Loss   | PnL: $ -3,194.95 | Trades:   15 | Win Rate:  46.67%
# 2025-04: Profit | PnL: $    552.50 | Trades:   16 | Win Rate:  50.00%
# 2025-05: Profit | PnL: $  5,006.57 | Trades:   39 | Win Rate:  58.97%
# 2025-06: Profit | PnL: $  4,302.23 | Trades:    8 | Win Rate:  75.00%
# 2025-08: Loss   | PnL: $ -2,865.98 | Trades:    6 | Win Rate:  33.33%
# ============================================================

# %% [markdown]
# 預測信心調整部位

# %%
class L1LeverageStrategy:
    """L1 策略 + ML 預測篩選 + 槓桿調整"""

    def __init__(
        self,
        entry_param: float = 0.5,
        rolling_window: int = 460,
        ml_pred_file: str = 'Pred_xgb.csv',
        allowed_predicted_labels: Optional[Iterable[int]] = None,
        leverage_map: Optional[Dict[int, float]] = None,
    ):
        self.entry_param = entry_param
        self.rolling_window = rolling_window
        self.ml_pred_file = ml_pred_file
        self.signals = None

        # 允許的 predicted_label；None 代表不過濾
        self.allowed_predicted_labels = (
            set(allowed_predicted_labels) if allowed_predicted_labels is not None else None
        )

        # 保留舊有映射 (可能仍需 fallback)
        self.leverage_map = leverage_map or {-1: 0.5, 0: 1.0, 1: 2.0}

        self.ml_predictions = None
        self.ml_predicted_labels = None
        self.ml_prediction_confidence = None
        self.ml_start_time = None

        self._load_ml_predictions()

    def _load_ml_predictions(self):
        """載入 ML 預測檔（須含 Date、predicted_label、prediction_confidence 欄位）"""
        try:
            ml_df = pd.read_csv(self.ml_pred_file)

            date_col = 'Date' if 'Date' in ml_df.columns else ml_df.columns[0]
            ml_df[date_col] = pd.to_datetime(ml_df[date_col])
            ml_df.set_index(date_col, inplace=True)
            ml_df.sort_index(inplace=True)

            if 'predicted_label' not in ml_df.columns:
                raise ValueError(f"{self.ml_pred_file} 缺少 predicted_label 欄位")
            if 'prediction_confidence' not in ml_df.columns:
                raise ValueError(f"{self.ml_pred_file} 缺少 prediction_confidence 欄位")

            self.ml_predicted_labels = ml_df['predicted_label']
            self.ml_prediction_confidence = (
                ml_df['prediction_confidence']
                .astype(float)
                .clip(lower=0.0)
                .fillna(0.0)
            )

            # 根據 label + confidence 轉成槓桿
            leverage_series = pd.Series(1.0, index=ml_df.index, dtype=float)
            # leverage_series[self.ml_predicted_labels == -1] = 1.0
            # 修正版本 - 使用 clip 方法
            leverage_series[self.ml_predicted_labels == -1] = (
                1.0 - (self.ml_prediction_confidence * 1.0).clip(upper=0.66)
            )
            leverage_series[self.ml_predicted_labels == 1] = (
                1.0 + (self.ml_prediction_confidence * 4.0)  # 建議加上槓桿上限
            )
            self.ml_predictions = leverage_series
            self.ml_start_time = leverage_series.index[0]

            print(f"✅ 載入 {self.ml_pred_file}：{len(self.ml_predictions):,} 筆")
            print(f"   時間範圍：{self.ml_predictions.index[0]} ~ {self.ml_predictions.index[-1]}")
            print("   predicted_label 分布：")
            for label, count in self.ml_predicted_labels.value_counts().sort_index().items():
                print(f"     {label}: {count:,}")
        except Exception as e:
            print(f"⚠️ 載入 ML 預測失敗：{e}")
            self.ml_predictions = pd.Series(dtype=float)
            self.ml_predicted_labels = pd.Series(dtype=float)
            self.ml_prediction_confidence = pd.Series(dtype=float)
            self.ml_start_time = None

    def calculate_indicators(self, df: pd.DataFrame) -> pd.DataFrame:
        df = df.copy()

        if self.ml_start_time is not None:
            df = df.loc[df.index >= self.ml_start_time].copy()
        else:
            print("⚠️ 尚未讀到 ML 預測資料，使用全部價格資料")

        df['HL115'] = (
            df['High'].shift(1).rolling(self.rolling_window, min_periods=self.rolling_window).max()
            - df['Low'].shift(1).rolling(self.rolling_window, min_periods=self.rolling_window).min()
        )
        df['HL115%'] = df['HL115'] / df['Low'].shift(self.rolling_window + 1)

        df['突破signal價'] = (
            df['Low'].shift(1).rolling(self.rolling_window).min() + self.entry_param * df['HL115']
        )
        df['突破signal價%'] = df['突破signal價'] / df['Open']

        df['signal'] = False
        df['signal'] = (
            (df['signal'].shift(1) == False)
            & (df['High'] > df['突破signal價'])
            & (df['Open'] < df['突破signal價'])
        )

        df['leverage'] = 1.0
        df['predicted_label'] = np.nan

        if self.ml_predictions is not None and len(self.ml_predictions) > 0:
            aligned_labels = self.ml_predicted_labels.reindex(df.index, method='ffill')
            aligned_leverage = self.ml_predictions.reindex(df.index, method='ffill').fillna(1.0)

            df['predicted_label'] = aligned_labels
            df['leverage'] = aligned_leverage

            signal_labels = df.loc[df['signal'], 'predicted_label'].dropna()
            matched = len(signal_labels)
            total_signals = int(df['signal'].sum())
            print(f"✅ L1 信號 {total_signals:,} 筆，成功匹配 {matched:,} 筆 ML 預測")
            if matched > 0:
                for label, count in signal_labels.value_counts().sort_index().items():
                    lev_desc = "1 - conf" if label == -1 else ("1 + conf" if label == 1 else "1")
                    print(f"   predicted_label={label}: {count:,} (leverage rule: {lev_desc})")
        else:
            print("⚠️ 無 ML 槓桿資料，全部使用 1.0x")

        if self.allowed_predicted_labels is not None:
            allowed_mask = df['predicted_label'].isin(self.allowed_predicted_labels).fillna(False)
            blocked = int(df['signal'].sum() - (df['signal'] & allowed_mask).sum())
            df['signal'] = df['signal'] & allowed_mask
            df.loc[~allowed_mask, 'leverage'] = 1.0
            print(f"🔍 ML 過濾：排除 {blocked:,} 筆不在 {sorted(self.allowed_predicted_labels)} 的信號")

        df['side'] = np.nan
        df.loc[df['signal'], 'side'] = 1.0
        df['side'] = df['side'].ffill()

        self.signals = df

        signal_df = df[df['signal']]
        leverage_counts = signal_df['leverage'].round(4).value_counts().sort_index()

        print("=" * 60)
        print("📊 L1 + ML 策略統計")
        print("=" * 60)
        print(f"總 K 線數: {len(df):,}")
        print(f"L1 信號數: {len(signal_df):,}")
        for lev, count in leverage_counts.items():
            print(f"  槓桿 {lev}x: {count:,} 筆")
        print("=" * 60)

        return df

    def get_signal_events(self) -> pd.DatetimeIndex:
        if self.signals is None:
            print("⚠️ 請先執行 calculate_indicators()")
            return None
        return self.signals.index[self.signals['signal']]

    def get_signal_stats(self) -> dict:
        if self.signals is None:
            return {}
        sig = self.signals[self.signals['signal']]
        total = len(sig)
        counts = sig['leverage'].value_counts().to_dict()
        return {
            'total_signals': total,
            'signal_rate': total / len(self.signals),
            'leverage_counts': counts,
            'avg_HL115': self.signals['HL115'].mean(),
            'avg_price_to_signal': (self.signals['Close'] / self.signals['突破signal價']).mean(),
        }

# %%
# 使用範例
# 假設你已經載入 nas100_raw (含 Open/High/Low/Close)

# dt et lightgbm lr nb rf svm xgboost
ML_PRED_FILE = r'C:\Users\a124a\OneDrive\桌面\策略開發\MetaLabelLearning\MetaNewHigh\pred_results\pred_xgboost_2020_2025.csv'      
ALLOWED_PRED_LABELS = {1, 0, -1}                # 只允許 predicted_label = 1 或 0 進場
# LEVERAGE_MAP = {-1: 1, 0: 1, 1: 1}    # 需要的槓桿對應
LEVERAGE_MAP = {-1: 0.5, 0: 1, 1: 2} 

# 1. 初始化策略（結合 L1 + ML）
strategy = L1LeverageStrategy(
    entry_param=1,
    rolling_window=96,
    ml_pred_file=ML_PRED_FILE,
    allowed_predicted_labels=None,
)
df_with_signals = strategy.calculate_indicators(nas100_raw)

# 2. 初始化回測引擎（例：0.25% 停損，32 根 K 停利）
# backtest = BacktestEngine(stop_loss_pct=0.0025, take_profit_bars=32)
backtest = BacktestEngine(stop_loss_pct=0.0025, take_profit_bars=32, take_profit_pct=0.0025)


# 3. 執行回測
results = backtest.backtest(
    df=df_with_signals[['Open', 'High', 'Low', 'Close']],
    signals=df_with_signals['signal'],
    leverage_series=df_with_signals['leverage']  # 傳入 ML 調整後的槓桿
)

# 4. 查看結果
print("\n前10筆交易:")
print(results.head(10))

# 5. 查看績效摘要與圖表
backtest.print_summary()
backtest.plot_equity_curve()

# 6. 詳細指標與每月統計
metrics = backtest.get_performance_metrics()
print("\n詳細績效指標:")
for key, value in metrics.items():
    print(f"{key}: {value}")

backtest.print_monthly_summary()
backtest.plot_monthly_pnl()
monthly_stats = backtest.get_monthly_statistics()
# Out:
# ✅ 載入 C:\Users\a124a\OneDrive\桌面\策略開發\MetaLabelLearning\MetaNewHigh\pred_results\pred_xgboost_2020_2025.csv：4,010 筆
#    時間範圍：2020-01-29 01:30:00 ~ 2025-08-11 03:15:00
#    predicted_label 分布：
#      -1: 2,365
#      0: 176
#      1: 1,469
# ✅ L1 信號 6,776 筆，成功匹配 6,776 筆 ML 預測
#    predicted_label=-1: 3,618 (leverage rule: 1 - conf)
#    predicted_label=0: 246 (leverage rule: 1)
#    predicted_label=1: 2,912 (leverage rule: 1 + conf)
# ============================================================
# 📊 L1 + ML 策略統計
# ============================================================
# 總 K 線數: 133,421
# L1 信號數: 6,776
#   槓桿 0.34x: 1,768 筆
#   槓桿 0.3411x: 3 筆
#   槓桿 0.3415x: 4 筆
#   槓桿 0.3418x: 9 筆
#   槓桿 0.3421x: 2 筆
#   槓桿 0.3422x: 1 筆
#   槓桿 0.3437x: 9 筆
#   槓桿 0.3442x: 2 筆
#   槓桿 0.3446x: 37 筆
#   槓桿 0.3465x: 1 筆
#   槓桿 0.3469x: 1 筆
#   槓桿 0.3476x: 15 筆
#   槓桿 0.3502x: 17 筆
#   槓桿 0.3513x: 1 筆
#   槓桿 0.3522x: 3 筆
#   槓桿 0.3525x: 1 筆
#   槓桿 0.3534x: 2 筆
#   槓桿 0.3535x: 4 筆
#   槓桿 0.3536x: 4 筆
#   槓桿 0.3557x: 14 筆
#   槓桿 0.359x: 1 筆
#   槓桿 0.3598x: 1 筆
#   槓桿 0.3611x: 4 筆
#   槓桿 0.3616x: 1 筆
#   槓桿 0.3641x: 1 筆
#   槓桿 0.3647x: 1 筆
#   槓桿 0.3655x: 19 筆
#   槓桿 0.3657x: 31 筆
#   槓桿 0.3667x: 10 筆
#   槓桿 0.3685x: 3 筆
#   槓桿 0.3711x: 1 筆
#   槓桿 0.3727x: 17 筆
#   槓桿 0.3728x: 2 筆
#   槓桿 0.3741x: 15 筆
#   槓桿 0.3743x: 1 筆
#   槓桿 0.3752x: 1 筆
#   槓桿 0.3759x: 1 筆
#   槓桿 0.3771x: 16 筆
#   槓桿 0.3776x: 29 筆
#   槓桿 0.3794x: 1 筆
#   槓桿 0.3802x: 1 筆
#   槓桿 0.3827x: 1 筆
#   槓桿 0.3828x: 6 筆
#   槓桿 0.3831x: 8 筆
#   槓桿 0.3836x: 50 筆
#   槓桿 0.3851x: 1 筆
#   槓桿 0.3856x: 1 筆
#   槓桿 0.3871x: 1 筆
#   槓桿 0.3885x: 2 筆
#   槓桿 0.3889x: 1 筆
#   槓桿 0.3896x: 1 筆
#   槓桿 0.3898x: 3 筆
#   槓桿 0.3918x: 1 筆
#   槓桿 0.3931x: 1 筆
#   槓桿 0.396x: 275 筆
#   槓桿 0.3963x: 2 筆
#   槓桿 0.3984x: 1 筆
#   槓桿 0.4019x: 1 筆
#   槓桿 0.4027x: 1 筆
#   槓桿 0.4031x: 3 筆
#   槓桿 0.4037x: 1 筆
#   槓桿 0.404x: 1 筆
#   槓桿 0.4043x: 1 筆
#   槓桿 0.4054x: 34 筆
#   槓桿 0.4057x: 10 筆
#   槓桿 0.4076x: 2 筆
#   槓桿 0.4096x: 62 筆
#   槓桿 0.4097x: 18 筆
#   槓桿 0.4111x: 1 筆
#   槓桿 0.4112x: 1 筆
#   槓桿 0.4114x: 1 筆
#   槓桿 0.4123x: 17 筆
#   槓桿 0.4129x: 1 筆
#   槓桿 0.4141x: 98 筆
#   槓桿 0.4171x: 2 筆
#   槓桿 0.4174x: 1 筆
#   槓桿 0.4177x: 1 筆
#   槓桿 0.419x: 1 筆
#   槓桿 0.4198x: 4 筆
#   槓桿 0.4204x: 59 筆
#   槓桿 0.4207x: 2 筆
#   槓桿 0.4212x: 2 筆
#   槓桿 0.4214x: 1 筆
#   槓桿 0.4228x: 25 筆
#   槓桿 0.4232x: 2 筆
#   槓桿 0.4276x: 25 筆
#   槓桿 0.4288x: 4 筆
#   槓桿 0.4291x: 1 筆
#   槓桿 0.4294x: 2 筆
#   槓桿 0.4302x: 1 筆
#   槓桿 0.4312x: 2 筆
#   槓桿 0.433x: 1 筆
#   槓桿 0.4331x: 1 筆
#   槓桿 0.4335x: 1 筆
#   槓桿 0.4345x: 7 筆
#   槓桿 0.4374x: 1 筆
#   槓桿 0.4396x: 2 筆
#   槓桿 0.4403x: 1 筆
#   槓桿 0.4404x: 2 筆
#   槓桿 0.4405x: 21 筆
#   槓桿 0.4417x: 24 筆
#   槓桿 0.4423x: 1 筆
#   槓桿 0.4428x: 1 筆
#   槓桿 0.4469x: 1 筆
#   槓桿 0.4471x: 1 筆
#   槓桿 0.4475x: 11 筆
#   槓桿 0.4483x: 2 筆
#   槓桿 0.4502x: 4 筆
#   槓桿 0.4505x: 1 筆
#   槓桿 0.4515x: 2 筆
#   槓桿 0.4516x: 1 筆
#   槓桿 0.4538x: 5 筆
#   槓桿 0.4587x: 2 筆
#   槓桿 0.461x: 2 筆
#   槓桿 0.4613x: 7 筆
#   槓桿 0.4616x: 1 筆
#   槓桿 0.4617x: 3 筆
#   槓桿 0.4635x: 2 筆
#   槓桿 0.4646x: 1 筆
#   槓桿 0.4657x: 3 筆
#   槓桿 0.4661x: 1 筆
#   槓桿 0.4687x: 1 筆
#   槓桿 0.4689x: 2 筆
#   槓桿 0.4691x: 1 筆
#   槓桿 0.4709x: 1 筆
#   槓桿 0.4712x: 4 筆
#   槓桿 0.4713x: 10 筆
#   槓桿 0.4731x: 8 筆
#   槓桿 0.4746x: 2 筆
#   槓桿 0.4754x: 2 筆
#   槓桿 0.4789x: 24 筆
#   槓桿 0.4806x: 1 筆
#   槓桿 0.4849x: 1 筆
#   槓桿 0.4866x: 15 筆
#   槓桿 0.4878x: 2 筆
#   槓桿 0.4879x: 3 筆
#   槓桿 0.4887x: 1 筆
#   槓桿 0.4896x: 12 筆
#   槓桿 0.4902x: 5 筆
#   槓桿 0.4905x: 1 筆
#   槓桿 0.4919x: 1 筆
#   槓桿 0.4925x: 1 筆
#   槓桿 0.4926x: 19 筆
#   槓桿 0.4929x: 4 筆
#   槓桿 0.4938x: 7 筆
#   槓桿 0.4949x: 1 筆
#   槓桿 0.4951x: 1 筆
#   槓桿 0.4953x: 1 筆
#   槓桿 0.4955x: 6 筆
#   槓桿 0.4961x: 2 筆
#   槓桿 0.4973x: 11 筆
#   槓桿 0.4975x: 6 筆
#   槓桿 0.4988x: 7 筆
#   槓桿 0.4992x: 13 筆
#   槓桿 0.5019x: 9 筆
#   槓桿 0.5041x: 17 筆
#   槓桿 0.5047x: 1 筆
#   槓桿 0.5055x: 1 筆
#   槓桿 0.507x: 1 筆
#   槓桿 0.5078x: 1 筆
#   槓桿 0.5081x: 1 筆
#   槓桿 0.5095x: 1 筆
#   槓桿 0.5099x: 1 筆
#   槓桿 0.5113x: 15 筆
#   槓桿 0.5129x: 4 筆
#   槓桿 0.5137x: 1 筆
#   槓桿 0.5143x: 1 筆
#   槓桿 0.5147x: 1 筆
#   槓桿 0.5157x: 1 筆
#   槓桿 0.5158x: 3 筆
#   槓桿 0.5162x: 1 筆
#   槓桿 0.5176x: 1 筆
#   槓桿 0.5177x: 2 筆
#   槓桿 0.5192x: 3 筆
#   槓桿 0.5206x: 1 筆
#   槓桿 0.5216x: 9 筆
#   槓桿 0.522x: 1 筆
#   槓桿 0.523x: 1 筆
#   槓桿 0.5243x: 1 筆
#   槓桿 0.5248x: 1 筆
#   槓桿 0.5255x: 2 筆
#   槓桿 0.5259x: 1 筆
#   槓桿 0.5263x: 1 筆
#   槓桿 0.527x: 8 筆
#   槓桿 0.5285x: 18 筆
#   槓桿 0.529x: 1 筆
#   槓桿 0.533x: 2 筆
#   槓桿 0.5387x: 1 筆
#   槓桿 0.5392x: 98 筆
#   槓桿 0.5403x: 1 筆
#   槓桿 0.5406x: 2 筆
#   槓桿 0.5414x: 7 筆
#   槓桿 0.542x: 16 筆
#   槓桿 0.5437x: 1 筆
#   槓桿 0.5461x: 46 筆
#   槓桿 0.5477x: 5 筆
#   槓桿 0.5505x: 1 筆
#   槓桿 0.5511x: 1 筆
#   槓桿 0.555x: 1 筆
#   槓桿 0.5552x: 1 筆
#   槓桿 0.559x: 1 筆
#   槓桿 0.5646x: 3 筆
#   槓桿 0.5654x: 1 筆
#   槓桿 0.5675x: 113 筆
#   槓桿 0.5688x: 1 筆
#   槓桿 0.5726x: 1 筆
#   槓桿 0.577x: 1 筆
#   槓桿 0.5945x: 1 筆
#   槓桿 0.5965x: 1 筆
#   槓桿 0.5971x: 42 筆
#   槓桿 0.5999x: 14 筆
#   槓桿 0.6005x: 6 筆
#   槓桿 0.6052x: 4 筆
#   槓桿 0.6102x: 1 筆
#   槓桿 0.6216x: 2 筆
#   槓桿 0.6236x: 34 筆
#   槓桿 0.6291x: 1 筆
#   槓桿 0.6354x: 5 筆
#   槓桿 0.6411x: 4 筆
#   槓桿 0.6563x: 1 筆
#   槓桿 1.0x: 246 筆
#   槓桿 2.5279x: 25 筆
#   槓桿 2.5458x: 2 筆
#   槓桿 2.5537x: 1 筆
#   槓桿 2.5722x: 1 筆
#   槓桿 2.5737x: 8 筆
#   槓桿 2.5984x: 126 筆
#   槓桿 2.5988x: 1 筆
#   槓桿 2.6144x: 3 筆
#   槓桿 2.625x: 19 筆
#   槓桿 2.6441x: 1 筆
#   槓桿 2.6444x: 1 筆
#   槓桿 2.6634x: 80 筆
#   槓桿 2.675x: 1 筆
#   槓桿 2.6771x: 1 筆
#   槓桿 2.6785x: 1 筆
#   槓桿 2.6878x: 1 筆
#   槓桿 2.7012x: 5 筆
#   槓桿 2.7024x: 8 筆
#   槓桿 2.7311x: 30 筆
#   槓桿 2.7369x: 1 筆
#   槓桿 2.7372x: 2 筆
#   槓桿 2.7456x: 39 筆
#   槓桿 2.7513x: 3 筆
#   槓桿 2.7584x: 26 筆
#   槓桿 2.7608x: 1 筆
#   槓桿 2.764x: 9 筆
#   槓桿 2.7691x: 5 筆
#   槓桿 2.7829x: 1 筆
#   槓桿 2.7858x: 1 筆
#   槓桿 2.8023x: 8 筆
#   槓桿 2.8133x: 1 筆
#   槓桿 2.8148x: 2 筆
#   槓桿 2.8361x: 1 筆
#   槓桿 2.8488x: 2 筆
#   槓桿 2.8632x: 5 筆
#   槓桿 2.8635x: 1 筆
#   槓桿 2.8724x: 1 筆
#   槓桿 2.8741x: 1 筆
#   槓桿 2.8755x: 2 筆
#   槓桿 2.8809x: 2 筆
#   槓桿 2.8846x: 1 筆
#   槓桿 2.8908x: 1 筆
#   槓桿 2.8963x: 26 筆
#   槓桿 2.9064x: 1 筆
#   槓桿 2.9239x: 1 筆
#   槓桿 2.9249x: 1 筆
#   槓桿 2.9262x: 5 筆
#   槓桿 2.9267x: 4 筆
#   槓桿 2.9347x: 11 筆
#   槓桿 2.9372x: 1 筆
#   槓桿 2.9394x: 1 筆
#   槓桿 2.9409x: 2 筆
#   槓桿 2.9463x: 1 筆
#   槓桿 2.9528x: 7 筆
#   槓桿 2.9567x: 5 筆
#   槓桿 2.9639x: 1 筆
#   槓桿 2.965x: 1 筆
#   槓桿 2.9662x: 21 筆
#   槓桿 2.9678x: 1 筆
#   槓桿 2.9685x: 6 筆
#   槓桿 2.9687x: 29 筆
#   槓桿 2.9727x: 2 筆
#   槓桿 2.979x: 7 筆
#   槓桿 2.9835x: 9 筆
#   槓桿 2.9885x: 1 筆
#   槓桿 2.9901x: 1 筆
#   槓桿 2.9912x: 136 筆
#   槓桿 2.9939x: 3 筆
#   槓桿 2.9974x: 1 筆
#   槓桿 3.0176x: 1 筆
#   槓桿 3.0215x: 15 筆
#   槓桿 3.0243x: 118 筆
#   槓桿 3.0249x: 2 筆
#   槓桿 3.0292x: 16 筆
#   槓桿 3.0338x: 2 筆
#   槓桿 3.0398x: 1 筆
#   槓桿 3.0427x: 1 筆
#   槓桿 3.0486x: 1 筆
#   槓桿 3.0519x: 1 筆
#   槓桿 3.063x: 1 筆
#   槓桿 3.0641x: 1 筆
#   槓桿 3.0673x: 5 筆
#   槓桿 3.0685x: 1 筆
#   槓桿 3.079x: 1 筆
#   槓桿 3.0887x: 1 筆
#   槓桿 3.0899x: 1 筆
#   槓桿 3.1012x: 4 筆
#   槓桿 3.1113x: 22 筆
#   槓桿 3.1144x: 1 筆
#   槓桿 3.1148x: 1 筆
#   槓桿 3.1164x: 1 筆
#   槓桿 3.1179x: 5 筆
#   槓桿 3.1212x: 2 筆
#   槓桿 3.1269x: 4 筆
#   槓桿 3.145x: 1 筆
#   槓桿 3.1534x: 1 筆
#   槓桿 3.1557x: 2 筆
#   槓桿 3.1602x: 1 筆
#   槓桿 3.1609x: 3 筆
#   槓桿 3.1646x: 1 筆
#   槓桿 3.1649x: 1 筆
#   槓桿 3.1665x: 2 筆
#   槓桿 3.1708x: 1 筆
#   槓桿 3.1739x: 17 筆
#   槓桿 3.1784x: 8 筆
#   槓桿 3.1805x: 10 筆
#   槓桿 3.1809x: 13 筆
#   槓桿 3.1814x: 23 筆
#   槓桿 3.182x: 10 筆
#   槓桿 3.187x: 1 筆
#   槓桿 3.1885x: 1 筆
#   槓桿 3.1912x: 1 筆
#   槓桿 3.1917x: 1 筆
#   槓桿 3.1955x: 1 筆
#   槓桿 3.1957x: 10 筆
#   槓桿 3.197x: 1 筆
#   槓桿 3.1983x: 1 筆
#   槓桿 3.203x: 7 筆
#   槓桿 3.2076x: 11 筆
#   槓桿 3.2089x: 4 筆
#   槓桿 3.2152x: 3 筆
#   槓桿 3.2198x: 7 筆
#   槓桿 3.2259x: 2 筆
#   槓桿 3.228x: 7 筆
#   槓桿 3.23x: 1 筆
#   槓桿 3.242x: 1 筆
#   槓桿 3.249x: 1 筆
#   槓桿 3.2513x: 1 筆
#   槓桿 3.2566x: 1 筆
#   槓桿 3.2638x: 67 筆
#   槓桿 3.2704x: 1 筆
#   槓桿 3.2727x: 1 筆
#   槓桿 3.273x: 6 筆
#   槓桿 3.2746x: 8 筆
#   槓桿 3.2767x: 47 筆
#   槓桿 3.2772x: 1 筆
#   槓桿 3.2833x: 1 筆
#   槓桿 3.2855x: 1 筆
#   槓桿 3.2908x: 1 筆
#   槓桿 3.2939x: 5 筆
#   槓桿 3.2976x: 1 筆
#   槓桿 3.3107x: 21 筆
#   槓桿 3.3161x: 1 筆
#   槓桿 3.3189x: 1 筆
#   槓桿 3.3349x: 3 筆
#   槓桿 3.349x: 3 筆
#   槓桿 3.3581x: 1 筆
#   槓桿 3.3625x: 1 筆
#   槓桿 3.3755x: 9 筆
#   槓桿 3.3827x: 3 筆
#   槓桿 3.3879x: 1 筆
#   槓桿 3.3891x: 3 筆
#   槓桿 3.3959x: 2 筆
#   槓桿 3.396x: 3 筆
#   槓桿 3.4028x: 4 筆
#   槓桿 3.4053x: 1 筆
#   槓桿 3.4111x: 1 筆
#   槓桿 3.4132x: 14 筆
#   槓桿 3.4231x: 2 筆
#   槓桿 3.4233x: 1 筆
#   槓桿 3.4306x: 1 筆
#   槓桿 3.4339x: 1 筆
#   槓桿 3.438x: 120 筆
#   槓桿 3.4439x: 1 筆
#   槓桿 3.4516x: 1 筆
#   槓桿 3.4584x: 29 筆
#   槓桿 3.4643x: 1 筆
#   槓桿 3.4646x: 1 筆
#   槓桿 3.4734x: 1 筆
#   槓桿 3.4758x: 1 筆
#   槓桿 3.4798x: 4 筆
#   槓桿 3.4821x: 3 筆
#   槓桿 3.4904x: 5 筆
#   槓桿 3.4917x: 1 筆
#   槓桿 3.4938x: 33 筆
#   槓桿 3.4955x: 1 筆
#   槓桿 3.5016x: 2 筆
#   槓桿 3.508x: 5 筆
#   槓桿 3.5117x: 26 筆
#   槓桿 3.5124x: 3 筆
#   槓桿 3.5143x: 13 筆
#   槓桿 3.5201x: 1 筆
#   槓桿 3.5238x: 1 筆
#   槓桿 3.5251x: 1 筆
#   槓桿 3.5274x: 1 筆
#   槓桿 3.528x: 32 筆
#   槓桿 3.53x: 1 筆
#   槓桿 3.5318x: 1 筆
#   槓桿 3.533x: 1 筆
#   槓桿 3.5362x: 9 筆
#   槓桿 3.5394x: 16 筆
#   槓桿 3.5449x: 2 筆
#   槓桿 3.5453x: 7 筆
#   槓桿 3.5587x: 17 筆
#   槓桿 3.5637x: 1 筆
#   槓桿 3.5755x: 2 筆
#   槓桿 3.5764x: 1 筆
#   槓桿 3.5783x: 15 筆
#   槓桿 3.5789x: 1 筆
#   槓桿 3.5931x: 3 筆
#   槓桿 3.5987x: 10 筆
#   槓桿 3.6041x: 1 筆
#   槓桿 3.6092x: 1 筆
#   槓桿 3.6125x: 1 筆
#   槓桿 3.6175x: 1 筆
#   槓桿 3.6216x: 7 筆
#   槓桿 3.6243x: 6 筆
#   槓桿 3.6456x: 7 筆
#   槓桿 3.6522x: 1 筆
#   槓桿 3.6572x: 1 筆
#   槓桿 3.6721x: 1 筆
#   槓桿 3.6757x: 1 筆
#   槓桿 3.6778x: 6 筆
#   槓桿 3.6862x: 1 筆
#   槓桿 3.6866x: 2 筆
#   槓桿 3.698x: 1 筆
#   槓桿 3.7073x: 2 筆
#   槓桿 3.7076x: 1 筆
#   槓桿 3.7081x: 147 筆
#   槓桿 3.7166x: 1 筆
#   槓桿 3.7195x: 4 筆
#   槓桿 3.7231x: 1 筆
#   槓桿 3.7328x: 19 筆
#   槓桿 3.7378x: 146 筆
#   槓桿 3.7444x: 4 筆
#   槓桿 3.7557x: 1 筆
#   槓桿 3.7594x: 1 筆
#   槓桿 3.7772x: 8 筆
#   槓桿 3.7875x: 4 筆
#   槓桿 3.7888x: 1 筆
#   槓桿 3.7894x: 5 筆
#   槓桿 3.792x: 8 筆
#   槓桿 3.8058x: 10 筆
#   槓桿 3.8153x: 1 筆
#   槓桿 3.8216x: 9 筆
#   槓桿 3.8292x: 1 筆
#   槓桿 3.8322x: 7 筆
#   槓桿 3.8797x: 1 筆
#   槓桿 3.8887x: 39 筆
#   槓桿 3.9097x: 1 筆
#   槓桿 3.9235x: 5 筆
#   槓桿 3.9261x: 1 筆
#   槓桿 3.9326x: 1 筆
#   槓桿 3.9367x: 1 筆
#   槓桿 3.9402x: 7 筆
#   槓桿 3.9448x: 1 筆
#   槓桿 3.9728x: 4 筆
#   槓桿 3.9758x: 55 筆
#   槓桿 3.9776x: 5 筆
#   槓桿 3.9827x: 8 筆
#   槓桿 4.0278x: 53 筆
#   槓桿 4.0335x: 1 筆
#   槓桿 4.0358x: 2 筆
#   槓桿 4.0391x: 1 筆
#   槓桿 4.0458x: 7 筆
#   槓桿 4.0539x: 3 筆
#   槓桿 4.0543x: 1 筆
#   槓桿 4.0564x: 1 筆
#   槓桿 4.0752x: 3 筆
#   槓桿 4.0834x: 24 筆
#   槓桿 4.0944x: 3 筆
#   槓桿 4.0989x: 1 筆
#   槓桿 4.1004x: 1 筆
#   槓桿 4.1069x: 1 筆
#   槓桿 4.1091x: 1 筆
#   槓桿 4.118x: 2 筆
#   槓桿 4.1305x: 1 筆
#   槓桿 4.1365x: 1 筆
#   槓桿 4.1612x: 1 筆
#   槓桿 4.1659x: 1 筆
#   槓桿 4.1761x: 1 筆
#   槓桿 4.1893x: 38 筆
#   槓桿 4.2086x: 7 筆
#   槓桿 4.218x: 1 筆
#   槓桿 4.223x: 1 筆
#   槓桿 4.2365x: 3 筆
#   槓桿 4.2933x: 1 筆
#   槓桿 4.2943x: 5 筆
#   槓桿 4.307x: 6 筆
#   槓桿 4.3235x: 1 筆
#   槓桿 4.3331x: 1 筆
#   槓桿 4.3391x: 3 筆
#   槓桿 4.3455x: 1 筆
#   槓桿 4.3605x: 5 筆
#   槓桿 4.3625x: 1 筆
#   槓桿 4.3637x: 1 筆
#   槓桿 4.3663x: 6 筆
#   槓桿 4.3734x: 1 筆
#   槓桿 4.3846x: 1 筆
#   槓桿 4.4046x: 1 筆
#   槓桿 4.4271x: 2 筆
#   槓桿 4.4294x: 1 筆
#   槓桿 4.4592x: 8 筆
#   槓桿 4.4848x: 238 筆
#   槓桿 4.4926x: 2 筆
#   槓桿 4.5621x: 149 筆
#   槓桿 4.5819x: 1 筆
#   槓桿 4.6108x: 3 筆
#   槓桿 4.6714x: 1 筆
#   槓桿 4.687x: 1 筆
#   槓桿 4.7166x: 14 筆
#   槓桿 4.7738x: 5 筆
#   槓桿 4.7939x: 2 筆
#   槓桿 4.8237x: 1 筆
#   槓桿 4.83x: 69 筆
# ============================================================
#
# 前10筆交易:
#            entry_time           exit_time  entry_price   exit_price  side  \
# 0 2020-01-30 04:00:00 2020-01-30 12:00:00      1579.85  1580.340000     1
# 1 2020-01-30 15:30:00 2020-01-30 16:45:00      1583.29  1579.331775     1
# 2 2020-01-30 17:30:00 2020-01-30 19:30:00      1585.45  1581.486375     1
# 3 2020-01-31 15:45:00 2020-01-31 16:45:00      1588.11  1584.139725     1
# 4 2020-01-31 20:15:00 2020-02-02 23:00:00      1588.47  1592.441175     1
# 5 2020-02-06 09:15:00 2020-02-06 10:45:00      1562.91  1566.817275     1
# 6 2020-02-06 11:00:00 2020-02-06 14:00:00      1566.29  1562.374275     1
# 7 2020-02-06 14:30:00 2020-02-06 15:45:00      1566.06  1562.144850     1
# 8 2020-02-07 00:45:00 2020-02-07 06:15:00      1568.30  1564.379250     1
# 9 2020-02-07 10:00:00 2020-02-07 12:45:00      1569.07  1565.147325     1
#
#         units  leverage   capital_used         pnl  return_pct  bars_held  \
# 0   33.356745  0.526987  100000.000000   11.074940    0.011075         32
# 1   33.287958  0.526987  100011.074940 -137.031675   -0.137017          5
# 2   33.197059  0.526987   99874.043265 -136.843919   -0.137017          8
# 3  237.984133  3.789408   99737.199346 -982.656951   -0.985246          4
# 4  235.585999  3.789408   98754.542395  898.131102    0.909458          7
# 5   36.181420  0.567454   99652.673497  135.715928    0.136189          6
# 6   36.152511  0.567454   99788.389425 -147.225821   -0.147538         12
# 7   36.104474  0.567454   99641.163604 -147.008607   -0.147538          5
# 8   35.999714  0.567454   99494.154997 -146.791713   -0.147538         22
# 9   35.928960  0.567454   99347.363284 -146.575140   -0.147538         11
#
#              exit_reason  stop_loss_price  take_profit_price   equity_after
# 0  Take Profit (32 bars)      1575.900375        1583.799625  100011.074940
# 1              Stop Loss      1579.331775        1587.248225   99874.043265
# 2              Stop Loss      1581.486375        1589.413625   99737.199346
# 3              Stop Loss      1584.139725        1592.080275   98754.542395
# 4    Take Profit (0.25%)      1584.498825        1592.441175   99652.673497
# 5    Take Profit (0.25%)      1559.002725        1566.817275   99788.389425
# 6              Stop Loss      1562.374275        1570.205725   99641.163604
# 7              Stop Loss      1562.144850        1569.975150   99494.154997
# 8              Stop Loss      1564.379250        1572.220750   99347.363284
# 9              Stop Loss      1565.147325        1572.992675   99200.788144
# ============================================================
# 📊 回測結果摘要（含動態槓桿調整 + 百分比停利）
# ============================================================
# 初始資金: $100,000.00
# 最終總equity: $144,342.80
# 總盈虧: $44,342.80
# 總報酬率: 44.34%
# 總交易次數: 2,254
# 獲利交易: 1,191
# 虧損交易: 1,063
# 勝率: 52.84%
# 平均報酬率: 0.02%
# 平均獲利: 0.43% ($463.80)
# 平均虧損: -0.44% ($-477.93)
# 獲利因子: 1.09
# 停損次數: 977
# 百分比停利次數 (0.25%): 1,136
#   0.25%停利賺錢出場: 1,136
#   0.25%停利虧錢出場: 0
# 時間停利次數 (32根K): 141
#   32根K後賺錢出場: 55
#   32根K後虧錢出場: 86
# 槓桿分布:
#   0.5x槓桿: 0
#   1.0x槓桿: 73
#   2.0x槓桿: 0
# ============================================================
# 詳細績效指標:
# Initial Capital: 100000
# Final Equity: 144342.80186841975
# Total PnL: 44342.80186841969
# Total Return (%): 44.34280186841975
# Total Trades: 2254
# Winning Trades: 1191
# Losing Trades: 1063
# Win Rate (%): 52.839396628216505
# Average Return (%): 0.017996249683532493
# Average Win (%): 0.42545203874412707
# Average Loss (%): -0.43852288932979594
# Average Win Amount: 463.7957822128211
# Average Loss Amount: -477.9284804769993
# Profit Factor: 1.0872824553922327
# Stop Loss Count: 977
# Take Profit Pct Count: 1136
# Take Profit Pct Win Count: 1136
# Take Profit Pct Loss Count: 0
# Take Profit Bars Count: 141
# Take Profit Bars Win Count: 55
# Take Profit Bars Loss Count: 86
# Leverage 0.5x Count: 0
# Leverage 1.0x Count: 73
# Leverage 2.0x Count: 0
# ============================================================
# 📊 每月統計摘要
# ============================================================
# 總月份數: 69
# 賺錢月份: 40 (57.97%)
# 虧錢月份: 29 (42.03%)
# ============================================================
#
# 每月詳細統計:
# ------------------------------------------------------------
# 2020-01: Loss   | PnL: $ -1,245.46 | Trades:    4 | Win Rate:  25.00%
# 2020-02: Profit | PnL: $  1,455.90 | Trades:   36 | Win Rate:  58.33%
# 2020-03: Profit | PnL: $    557.18 | Trades:   55 | Win Rate:  58.18%
# 2020-04: Profit | PnL: $  4,333.87 | Trades:   59 | Win Rate:  52.54%
# 2020-05: Profit | PnL: $  1,720.38 | Trades:   34 | Win Rate:  52.94%
# 2020-06: Profit | PnL: $  1,328.53 | Trades:   34 | Win Rate:  50.00%
# 2020-07: Profit | PnL: $  4,934.08 | Trades:   45 | Win Rate:  57.78%
# 2020-08: Profit | PnL: $  1,588.38 | Trades:   48 | Win Rate:  56.25%
# 2020-09: Loss   | PnL: $ -2,261.13 | Trades:   36 | Win Rate:  44.44%
# 2020-10: Loss   | PnL: $   -342.54 | Trades:   29 | Win Rate:  44.83%
# 2020-11: Loss   | PnL: $   -338.23 | Trades:   24 | Win Rate:  45.83%
# 2020-12: Profit | PnL: $  4,419.17 | Trades:   41 | Win Rate:  58.54%
# 2021-01: Loss   | PnL: $ -1,745.29 | Trades:   28 | Win Rate:  50.00%
# 2021-02: Profit | PnL: $    571.54 | Trades:   15 | Win Rate:  46.67%
# 2021-03: Profit | PnL: $    100.38 | Trades:   30 | Win Rate:  53.33%
# 2021-04: Profit | PnL: $  3,198.70 | Trades:   35 | Win Rate:  60.00%
# 2021-05: Profit | PnL: $    879.00 | Trades:   43 | Win Rate:  53.49%
# 2021-06: Loss   | PnL: $   -443.61 | Trades:   18 | Win Rate:  33.33%
# 2021-07: Loss   | PnL: $   -426.84 | Trades:   35 | Win Rate:  42.86%
# 2021-08: Profit | PnL: $    665.04 | Trades:   33 | Win Rate:  60.61%
# 2021-09: Loss   | PnL: $   -460.81 | Trades:   18 | Win Rate:  38.89%
# 2021-10: Loss   | PnL: $   -961.54 | Trades:   30 | Win Rate:  50.00%
# 2021-11: Profit | PnL: $     23.33 | Trades:   30 | Win Rate:  40.00%
# 2021-12: Profit | PnL: $    317.62 | Trades:   31 | Win Rate:  54.84%
# 2022-01: Loss   | PnL: $ -3,821.24 | Trades:   26 | Win Rate:  38.46%
# 2022-02: Profit | PnL: $    751.98 | Trades:   42 | Win Rate:  61.90%
# 2022-03: Profit | PnL: $  2,060.05 | Trades:   42 | Win Rate:  54.76%
# 2022-04: Loss   | PnL: $   -192.74 | Trades:   27 | Win Rate:  48.15%
# 2022-05: Loss   | PnL: $ -2,843.62 | Trades:   29 | Win Rate:  41.38%
# 2022-06: Loss   | PnL: $ -5,546.58 | Trades:   27 | Win Rate:  37.04%
# 2022-07: Loss   | PnL: $ -3,717.77 | Trades:   25 | Win Rate:  44.00%
# 2022-08: Loss   | PnL: $ -3,021.72 | Trades:   25 | Win Rate:  44.00%
# 2022-09: Loss   | PnL: $ -2,523.63 | Trades:   25 | Win Rate:  44.00%
# 2022-10: Profit | PnL: $  5,402.80 | Trades:   26 | Win Rate:  65.38%
# 2022-11: Profit | PnL: $  6,465.95 | Trades:   39 | Win Rate:  64.10%
# 2022-12: Loss   | PnL: $ -4,157.44 | Trades:   38 | Win Rate:  52.63%
# 2023-01: Profit | PnL: $  3,122.30 | Trades:   37 | Win Rate:  56.76%
# 2023-02: Loss   | PnL: $ -4,683.89 | Trades:   18 | Win Rate:  33.33%
# 2023-03: Loss   | PnL: $ -3,601.29 | Trades:   54 | Win Rate:  50.00%
# 2023-04: Loss   | PnL: $ -4,095.03 | Trades:   23 | Win Rate:  39.13%
# 2023-05: Loss   | PnL: $ -4,618.97 | Trades:   26 | Win Rate:  38.46%
# 2023-06: Loss   | PnL: $ -1,771.03 | Trades:   17 | Win Rate:  35.29%
# 2023-07: Profit | PnL: $  1,222.90 | Trades:   28 | Win Rate:  53.57%
# 2023-08: Loss   | PnL: $ -1,952.99 | Trades:   15 | Win Rate:  40.00%
# 2023-09: Loss   | PnL: $ -1,109.22 | Trades:   15 | Win Rate:  33.33%
# 2023-10: Profit | PnL: $  2,121.73 | Trades:   39 | Win Rate:  61.54%
# 2023-11: Profit | PnL: $  4,965.54 | Trades:   23 | Win Rate:  60.87%
# 2023-12: Profit | PnL: $  1,756.27 | Trades:   31 | Win Rate:  54.84%
# 2024-01: Loss   | PnL: $ -3,706.66 | Trades:   25 | Win Rate:  44.00%
# 2024-02: Profit | PnL: $    347.51 | Trades:   21 | Win Rate:  52.38%
# 2024-03: Profit | PnL: $  3,328.41 | Trades:   36 | Win Rate:  55.56%
# 2024-04: Profit | PnL: $  9,182.95 | Trades:   36 | Win Rate:  66.67%
# 2024-05: Profit | PnL: $    445.30 | Trades:   37 | Win Rate:  59.46%
# 2024-06: Loss   | PnL: $ -7,919.61 | Trades:   31 | Win Rate:  35.48%
# 2024-07: Profit | PnL: $ 10,400.47 | Trades:   45 | Win Rate:  64.44%
# 2024-08: Loss   | PnL: $ -3,591.04 | Trades:   36 | Win Rate:  52.78%
# 2024-09: Profit | PnL: $  5,061.82 | Trades:   40 | Win Rate:  55.00%
# 2024-10: Loss   | PnL: $   -892.24 | Trades:   42 | Win Rate:  50.00%
# 2024-11: Profit | PnL: $  3,376.66 | Trades:   36 | Win Rate:  58.33%
# 2024-12: Profit | PnL: $  4,652.42 | Trades:   24 | Win Rate:  62.50%
# 2025-01: Profit | PnL: $  7,350.62 | Trades:   48 | Win Rate:  64.58%
# 2025-02: Profit | PnL: $  2,042.68 | Trades:   37 | Win Rate:  59.46%
# 2025-03: Loss   | PnL: $   -776.06 | Trades:   47 | Win Rate:  59.57%
# 2025-04: Profit | PnL: $  8,009.66 | Trades:   63 | Win Rate:  57.14%
# 2025-05: Profit | PnL: $  4,621.94 | Trades:   39 | Win Rate:  58.97%
# 2025-06: Profit | PnL: $  2,113.43 | Trades:   34 | Win Rate:  47.06%
# 2025-07: Profit | PnL: $    279.57 | Trades:   32 | Win Rate:  56.25%
# 2025-08: Profit | PnL: $  1,379.08 | Trades:   30 | Win Rate:  53.33%
# 2025-09: Profit | PnL: $    555.95 | Trades:   27 | Win Rate:  59.26%
# ============================================================
